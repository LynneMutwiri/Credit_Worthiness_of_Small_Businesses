# %% [markdown]
# ### **CREDIT-WORTHINESS OF SMALL BUSINESSES**
# #### Case study of small businesses guaranteed by the U.S. Small Business Administration(SBA)

# %% [markdown]
# ### **Business Overview**
#
# The Small Business Administration (SBA) is a crucial organization in the United States that supports and promotes small enterprises by providing access to credit. Through loan guarantees, the SBA encourages lenders to provide credit to small businesses, which play a vital role in job creation and reducing unemployment. However, there have been instances of loan defaults, posing a challenge for the SBA in accurately assessing the creditworthiness of applicants and mitigating risks. To address this, the SBA focuses on evaluating creditworthiness by considering factors such as financial history, business plans, collateral, and projected cash flows. They also strive to adapt to market dynamics, embracing innovative approaches and technology for informed lending decisions that minimize the likelihood of defaults. Overall, the SBA's commitment to supporting small businesses goes beyond loan guarantees, encompassing mentorship programs, training resources, government contracting opportunities, and disaster recovery assistance to foster an environment conducive to small business success.

# %% [markdown]
# ### Project Overview
#
# This project focuses on utilizing the dataset from the U.S. Small Business Administration to develop a predictive model for loan application approval. By analyzing relevant factors and historical loan data, the project aims to create a reliable system that assists the SBA in making informed decisions while minimizing the risk of defaults. The ultimate goal is to provide the SBA with a robust loan approval model that enhances their ability to make accurate and efficient lending decisions.

# %% [markdown]
# ### Objectives
#
# 1. Conduct a comprehensive analysis of the dataset from the U.S. Small Business Administration to identify patterns and trends for accurate loan approval predictions.
# 2. Develop a robust machine learning model that utilizes the identified patterns and trends to predict loan approval outcomes effectively.
# 3. Deploy and evaluate the developed machine learning model in the loan approval process of the U.S. Small Business Administration, continuously optimizing its predictive capabilities for informed lending decisions.

# %% [markdown]
# ### Small Exercise

# %% [markdown]
# ### Data Understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
pd.set_option('display.max_columns', None)
from sklearn.preprocessing import LabelEncoder
import warnings

# %% [markdown]
# ## Question Lynne Asked ( Model Input )
# 1. Business Name
# 2. Amount of Loan
# 3. Loan Repayment Period
# 4. Pay Previous Loan Status
# 5. No.of Employees
# 6. Business Location
# 7. Business Industry
# 8. How long has business been in operation
#
# ## Expected Answer
# 1. Whether loan is guaranteed or not
# 2. Major factors that led to loan results
# 3. Most Probable Banks

# %%
df = pd.read_csv('data/SBAnational.csv')
df.head()
# Out:
# C:\Users\ABDALLAH\AppData\Local\Temp\ipykernel_6924\360885582.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/SBAnational.csv')
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
#    Term  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0    84      4       2.0          0            0              1           0
# 1    60      2       2.0          0            0              1           0
# 2   180      7       1.0          0            0              1           0
# 3    60      2       1.0          0            0              1           0
# 4   240     14       1.0          7            7              1           0
#
#   RevLineCr LowDoc ChgOffDate DisbursementDate DisbursementGross BalanceGross  \
# 0         N      Y        NaN        28-Feb-99       $60,000.00        $0.00
# 1         N      Y        NaN        31-May-97       $40,000.00        $0.00
# 2         N      N        NaN        31-Dec-97      $287,000.00        $0.00
# 3         N      Y        NaN        30-Jun-97       $35,000.00        $0.00
# 4         N      N        NaN        14-May-97      $229,000.00        $0.00
#
#   MIS_Status ChgOffPrinGr        GrAppv      SBA_Appv
# 0      P I F       $0.00    $60,000.00    $48,000.00
# 1      P I F       $0.00    $40,000.00    $32,000.00
# 2      P I F       $0.00   $287,000.00   $215,250.00
# 3      P I F       $0.00    $35,000.00    $28,000.00
# 4      P I F       $0.00   $229,000.00   $229,000.00

# %%
df.NewExist.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model Input
# loan amount= gross Approved
#
# repayment period = term
#
# no_employees = no_employees
#
# business_location = urban_rural
#
# business_industry = industry
#
#
# ## Model Output
# MIS_staus = mis_status

# %%
0.9*60000
# Out:
# 54000.0

# %%
df2 = pd.read_csv("data/foia-7afy2020-present-asof-230331.csv",encoding='latin-1', engine='python')
df2.head()
# Out:
#    AsOfDate Program                       BorrName  \
# 0  20230331      7A  Allen Foot and Ankle Medicine
# 1  20230331      7A         Cojutepeque Restaurant
# 2  20230331      7A                       Adwa LLC
# 3  20230331      7A                  Town Cleaners
# 4  20230331      7A                      Moor Inc.
#
#                        BorrStreet      BorrCity BorrState  BorrZip  \
# 0     2919 S ELLSWORTH RD STE 124          MESA        AZ    85212
# 1                   2610 W 3rd St   Los Angeles        CA    90057
# 2  3105 ALDERWOOD MALL BLVD Suite      LYNNWOOD        WA    98036
# 3         2700 WASHINGTON BLVD #B     ARLINGTON        VA    22201
# 4                 524 WOODSIDE RD  REDWOOD CITY        CA    94061
#
#                                     BankName  BankFDICNumber  BankNCUANumber  \
# 0                      Western Alliance Bank         57512.0             NaN
# 1                                Banner Bank         28489.0             NaN
# 2                                Umpqua Bank         17266.0             NaN
# 3                                 Hanmi Bank         24170.0             NaN
# 4  JPMorgan Chase Bank, National Association           628.0             NaN
#
#                  BankStreet     BankCity BankState  BankZip  GrossApproval  \
# 0         1 E Washington St      PHOENIX        AZ  85004.0       350000.0
# 1            10 S First Ave  WALLA WALLA        WA  99362.0      1040000.0
# 2  445 SE Main St, First Fl     ROSEBURG        OR  97470.0       987500.0
# 3  3660 Wilshire Blvd, PH-A  LOS ANGELES        CA  90010.0        22000.0
# 4         1111 Polaris Pkwy     COLUMBUS        OH  43240.0        49000.0
#
#    SBAGuaranteedApproval ApprovalDate  ApprovalFiscalYear  \
# 0               175000.0   10/01/2019                2020
# 1               780000.0   10/01/2019                2020
# 2               740625.0   10/01/2019                2020
# 3                11000.0   10/01/2019                2020
# 4                24500.0   10/01/2019                2020
#
#   FirstDisbursementDate DeliveryMethod                   subpgmdesc  \
# 0            10/31/2019     SBA EXPRES  FA$TRK (Small Loan Express)
# 1            10/31/2019            PLP                     Guaranty
# 2            10/31/2019            PLP                     Guaranty
# 3            10/31/2019     SBA EXPRES  FA$TRK (Small Loan Express)
# 4            10/31/2019     SBA EXPRES  FA$TRK (Small Loan Express)
#
#    InitialInterestRate  TermInMonths  NaicsCode  \
# 0                  5.5            63   621391.0
# 1                  6.5           300   722511.0
# 2                  7.0           120   451110.0
# 3                  9.0            51   812320.0
# 4                 11.5           120   445110.0
#
#                                     NaicsDescription FranchiseCode  \
# 0                             Offices of Podiatrists           NaN
# 1                           Full-Service Restaurants           NaN
# 2                              Sporting Goods Stores           NaN
# 3  Drycleaning and Laundry Services (except Coin-...           NaN
# 4  Supermarkets and Other Grocery (except Conveni...           NaN
#
#   FranchiseName ProjectCounty ProjectState              SBADistrictOffice  \
# 0           NaN      MARICOPA           AZ        ARIZONA DISTRICT OFFICE
# 1           NaN   LOS ANGELES           CA    LOS ANGELES DISTRICT OFFICE
# 2           NaN     SNOHOMISH           WA        SEATTLE DISTRICT OFFICE
# 3           NaN     ARLINGTON           VA     WASHINGTON DISTRICT OFFICE
# 4           NaN     SAN MATEO           CA  SAN FRANCISCO DISTRICT OFFICE
#
#    CongressionalDistrict BusinessType                        BusinessAge  \
# 0                    4.0  CORPORATION  Existing or more than 2 years old
# 1                   34.0  CORPORATION  Existing or more than 2 years old
# 2                    1.0  CORPORATION                Change of Ownership
# 3                    8.0   INDIVIDUAL  Existing or more than 2 years old
# 4                   14.0  CORPORATION  Existing or more than 2 years old
#
#   LoanStatus PaidInFullDate ChargeOffDate  GrossChargeOffAmount  \
# 0        PIF     12/31/2022           NaN                     0
# 1     EXEMPT            NaN           NaN                     0
# 2     EXEMPT            NaN           NaN                     0
# 3     CHGOFF            NaN    09/07/2022                 15570
# 4        PIF     01/31/2023           NaN                     0
#
#    RevolverStatus  JobsSupported SOLDSECMRTIND
# 0               0              0             N
# 1               0             12             Y
# 2               0             14             Y
# 3               0              2             Y
# 4               1              0             N

# %%
df2[df2.NaicsCode==621210]
# Out:
#         AsOfDate Program                       BorrName  \
# 69      20230331      7A     Stratton Family Dental LLC
# 204     20230331      7A        Frenchtown  Dental PLLC
# 265     20230331      7A     Khushboo Jain Property LLC
# 278     20230331      7A         Floss Family Dentistry
# 292     20230331      7A               Tellosmiles PLLC
# ...          ...     ...                            ...
# 167401  20230331      7A   Nestor L. Aquino D.M.D. A Pr
# 167667  20230331      7A          Oral Dental Care P.C.
# 167678  20230331      7A             YAK Properties LLC
# 167814  20230331      7A  Lake Manassas Dental Center P
# 167999  20230331      7A             CK Texas Dental PC
#
#                           BorrStreet       BorrCity BorrState  BorrZip  \
# 69                   310 S.  5TH AVE      PRINCETON        IN    47670
# 204                16332 BECKWITH ST     FRENCHTOWN        MT    59834
# 265          2010 John Rolfe Parkway        Henrico        VA    23238
# 278            2176 WEST MAIN STREET           LEHI        UT    84043
# 292                     1130 14Th St     Texas City        TX    77590
# ...                              ...            ...       ...      ...
# 167401            3119 Glendale Blvd    LOS ANGELES        CA    90039
# 167667              1412 RICHMOND RD  STATEN ISLAND        NY    10304
# 167678               2016 S Broadway      OAK GROVE        MO    64075
# 167814  7915 LAKE MANASSAS DR STE 11    GAINESVILLE        VA    20155
# 167999         8994 Tour Drive, #220       MCKINNEY        TX    75070
#
#                                      BankName  BankFDICNumber  BankNCUANumber  \
# 69                   Live Oak Banking Company         58665.0             NaN
# 204                  Live Oak Banking Company         58665.0             NaN
# 265     Bank of America, National Association          3510.0             NaN
# 278                  Live Oak Banking Company         58665.0             NaN
# 292                          Texas First Bank         23799.0             NaN
# ...                                       ...             ...             ...
# 167401                 BayFirst National Bank         34997.0             NaN
# 167667                 BayFirst National Bank         34997.0             NaN
# 167678         UMB Bank, National Association          8273.0             NaN
# 167814                 BayFirst National Bank         34997.0             NaN
# 167999                              Open Bank         57944.0             NaN
#
#                          BankStreet          BankCity BankState  BankZip  \
# 69                  1741 Tiburon Dr        WILMINGTON        NC  28403.0
# 204                 1741 Tiburon Dr        WILMINGTON        NC  28403.0
# 265         100 N Tryon St, Ste 170         CHARLOTTE        NC  28202.0
# 278                 1741 Tiburon Dr        WILMINGTON        NC  28403.0
# 292                 3232 Palmer Hwy        TEXAS CITY        TX  77590.0
# ...                             ...               ...       ...      ...
# 167401           700 Central Avenue  Saint Petersburg        FL  33701.0
# 167667           700 Central Avenue  Saint Petersburg        FL  33701.0
# 167678              1010 Grand Blvd       KANSAS CITY        MO  64106.0
# 167814           700 Central Avenue  Saint Petersburg        FL  33701.0
# 167999  1000 Wilshire Blvd, Ste 500       LOS ANGELES        CA  90017.0
#
#         GrossApproval  SBAGuaranteedApproval ApprovalDate  ApprovalFiscalYear  \
# 69           700000.0               525000.0   10/01/2019                2020
# 204         2100000.0              1575000.0   10/02/2019                2020
# 265          245500.0               184125.0   10/02/2019                2020
# 278         1155000.0               866250.0   10/02/2019                2020
# 292          305000.0               228750.0   10/02/2019                2020
# ...               ...                    ...          ...                 ...
# 167401        81500.0                69275.0   03/28/2023                2023
# 167667       150000.0               127500.0   03/29/2023                2023
# 167678       278700.0               209025.0   03/29/2023                2023
# 167814       150000.0               127500.0   03/30/2023                2023
# 167999      1220000.0               915000.0   03/31/2023                2023
#
#        FirstDisbursementDate DeliveryMethod subpgmdesc  InitialInterestRate  \
# 69                02/03/2020            PLP   Guaranty                 6.25
# 204               11/30/2019            PLP   Guaranty                 5.74
# 265               10/31/2019            PLP   Guaranty                 4.99
# 278               01/24/2020            PLP   Guaranty                 6.00
# 292               10/31/2019         OTH 7A   Guaranty                 6.00
# ...                      ...            ...        ...                  ...
# 167401                   NaN            PLP   Guaranty                11.50
# 167667                   NaN            PLP   Guaranty                11.50
# 167678                   NaN            PLP   Guaranty                 7.24
# 167814                   NaN            PLP   Guaranty                11.50
# 167999                   NaN            PLP   Guaranty                 9.00
#
#         TermInMonths  NaicsCode     NaicsDescription FranchiseCode  \
# 69               306   621210.0  Offices of Dentists           NaN
# 204              312   621210.0  Offices of Dentists           NaN
# 265              300   621210.0  Offices of Dentists           NaN
# 278              126   621210.0  Offices of Dentists           NaN
# 292              210   621210.0  Offices of Dentists           NaN
# ...              ...        ...                  ...           ...
# 167401           120   621210.0  Offices of Dentists           NaN
# 167667           120   621210.0  Offices of Dentists           NaN
# 167678           300   621210.0  Offices of Dentists           NaN
# 167814           120   621210.0  Offices of Dentists           NaN
# 167999           300   621210.0  Offices of Dentists           NaN
#
#        FranchiseName   ProjectCounty ProjectState  \
# 69               NaN          GIBSON           IN
# 204              NaN        MISSOULA           MT
# 265              NaN         HENRICO           VA
# 278              NaN            UTAH           UT
# 292              NaN       GALVESTON           TX
# ...              ...             ...          ...
# 167401           NaN     LOS ANGELES           CA
# 167667           NaN        RICHMOND           NY
# 167678           NaN         JACKSON           MO
# 167814           NaN  PRINCE WILLIAM           VA
# 167999           NaN          COLLIN           TX
#
#                         SBADistrictOffice  CongressionalDistrict BusinessType  \
# 69                INDIANA DISTRICT OFFICE                    8.0  CORPORATION
# 204               MONTANA DISTRICT OFFICE                    0.0  CORPORATION
# 265              RICHMOND DISTRICT OFFICE                    7.0  CORPORATION
# 278                  UTAH DISTRICT OFFICE                    3.0  CORPORATION
# 292               HOUSTON DISTRICT OFFICE                   14.0  CORPORATION
# ...                                   ...                    ...          ...
# 167401        LOS ANGELES DISTRICT OFFICE                   28.0  CORPORATION
# 167667           NEW YORK DISTRICT OFFICE                   11.0  CORPORATION
# 167678        KANSAS CITY DISTRICT OFFICE                    5.0  CORPORATION
# 167814           RICHMOND DISTRICT OFFICE                    1.0  CORPORATION
# 167999  DALLAS / FT WORTH DISTRICT OFFICE                    3.0  CORPORATION
#
#                                    BusinessAge LoanStatus PaidInFullDate  \
# 69           Existing or more than 2 years old     EXEMPT            NaN
# 204          Existing or more than 2 years old     EXEMPT            NaN
# 265                                 Unanswered     EXEMPT            NaN
# 278     Startup, Loan Funds will Open Business     EXEMPT            NaN
# 292     Startup, Loan Funds will Open Business     EXEMPT            NaN
# ...                                        ...        ...            ...
# 167401       Existing or more than 2 years old     COMMIT            NaN
# 167667       Existing or more than 2 years old     COMMIT            NaN
# 167678       Existing or more than 2 years old     COMMIT            NaN
# 167814       Existing or more than 2 years old     COMMIT            NaN
# 167999                     Change of Ownership     COMMIT            NaN
#
#        ChargeOffDate  GrossChargeOffAmount  RevolverStatus  JobsSupported  \
# 69               NaN                     0               0              2
# 204              NaN                     0               0              5
# 265              NaN                     0               0              1
# 278              NaN                     0               0              7
# 292              NaN                     0               0              5
# ...              ...                   ...             ...            ...
# 167401           NaN                     0               0              7
# 167667           NaN                     0               0              6
# 167678           NaN                     0               0              2
# 167814           NaN                     0               0              8
# 167999           NaN                     0               0              3
#
#        SOLDSECMRTIND
# 69                 Y
# 204                N
# 265                N
# 278                N
# 292                N
# ...              ...
# 167401           NaN
# 167667           NaN
# 167678           NaN
# 167814           NaN
# 167999           NaN
#
# [2164 rows x 40 columns]

# %%
df2.LoanStatus.value_counts()
# Out:
# EXEMPT    121746
# COMMIT     17858
# CANCLD     14980
# PIF        13147
# CHGOFF       480
# Name: LoanStatus, dtype: int64

# %%
len(df2)/len(df)
# Out:
# 0.18707488289121896

# %%
class Describer:
    
    # initialize object
    def __init__(self, df):
        self.df = df
        
    # method to check shape of data
    def shape(self):
        shape_df = print(f"The DataFrame has:\n\t* {self.df.shape[0]} rows\n\t* {self.df.shape[1]} columns", '\n')
        return shape_df
    
    # method to check info on dataset
    def data_info(self):
        info_df = print(self.df.info(), '\n')
        return info_df
    
    # method to describe numerical columns
    def data_describe(self):
        num_col = self.df.describe()
        return num_col

# %%
# creating an instance of the class describer
describe_df = Describer(df)

# lets view the shape of the data
describe_df.shape()
# Out:
# The DataFrame has:
# 	* 899164 rows
# 	* 27 columns

# %%
# print summary information of the dataset
print('Summary infomation on dataset')
print('-----------------------------------------------')
describe_df.data_info()
# Out:
# Summary infomation on dataset
# -----------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   LoanNr_ChkDgt      899164 non-null  int64
#  1   Name               899150 non-null  object
#  2   City               899134 non-null  object
#  3   State              899150 non-null  object
#  4   Zip                899164 non-null  int64
#  5   Bank               897605 non-null  object
#  6   BankState          897598 non-null  object
#  7   NAICS              899164 non-null  int64
#  8   ApprovalDate       899164 non-null  object
#  9   ApprovalFY         899164 non-null  object
#  10  Term               899164 non-null  int64
#  11  NoEmp              899164 non-null  int64
#  12  NewExist           899028 non-null  float64
#  13  CreateJob          899164 non-null  int64
#  14  RetainedJob        899164 non-null  int64
#  15  FranchiseCode      899164 non-null  int64
#  16  UrbanRural         899164 non-null  int64
#  17  RevLineCr          894636 non-null  object
#  18  LowDoc             896582 non-null  object
#  19  ChgOffDate         162699 non-null  object
#  20  DisbursementDate   896796 non-null  object
#  21  DisbursementGross  899164 non-null  object
#  22  BalanceGross       899164 non-null  object
#  23  MIS_Status         897167 non-null  object
#  24  ChgOffPrinGr       899164 non-null  object
#  25  GrAppv             899164 non-null  object
#  26  SBA_Appv           899164 non-null  object
# dtypes: float64(1), int64(9), object(17)
# memory usage: 185.2+ MB
# None

# %%
#summary statistics of the data
describe_df.data_describe()
# Out:
#        LoanNr_ChkDgt            Zip          NAICS           Term  \
# count   8.991640e+05  899164.000000  899164.000000  899164.000000
# mean    4.772612e+09   53804.391241  398660.950146     110.773078
# std     2.538175e+09   31184.159152  263318.312759      78.857305
# min     1.000014e+09       0.000000       0.000000       0.000000
# 25%     2.589758e+09   27587.000000  235210.000000      60.000000
# 50%     4.361439e+09   55410.000000  445310.000000      84.000000
# 75%     6.904627e+09   83704.000000  561730.000000     120.000000
# max     9.996003e+09   99999.000000  928120.000000     569.000000
#
#                NoEmp       NewExist      CreateJob    RetainedJob  \
# count  899164.000000  899028.000000  899164.000000  899164.000000
# mean       11.411353       1.280404       8.430376      10.797257
# std        74.108196       0.451750     236.688165     237.120600
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       1.000000       0.000000       0.000000
# 50%         4.000000       1.000000       0.000000       1.000000
# 75%        10.000000       2.000000       1.000000       4.000000
# max      9999.000000       2.000000    8800.000000    9500.000000
#
#        FranchiseCode     UrbanRural
# count  899164.000000  899164.000000
# mean     2753.725933       0.757748
# std     12758.019136       0.646436
# min         0.000000       0.000000
# 25%         1.000000       0.000000
# 50%         1.000000       1.000000
# 75%         1.000000       1.000000
# max     99999.000000       2.000000

# %%
# function to identify missing values

# identify missing 
def identify_missing_values(data):
    # identify if data has missing values
    # empty dict to store missing values
    missing = []
    for i in data.isnull().any():
        # add the bool values to empty list 
        missing.append(i)
    # covert list to set (if data has missing values, the list should have true and false)
    missing_set = set(missing)
    if (len(missing_set) == 1):
        out = print("The Data has no missing values")
    else:
        out = print("The Data has missing values.")

    return out

identify_missing_values(df)
# Out:
# The Data has missing values.

# %%
df.duplicated().any()
# Out:
# False

# %%
# function to display missing values

def missing_values(data):
    # identify the total missing values per column
    # sort in order 
    miss = data.isnull().sum().sort_values(ascending = False)

    # calculate percentage of the missing values
    percentage_miss = (data.isnull().sum() / len(data)).sort_values(ascending = False)

    # store in a dataframe 
    missing = pd.DataFrame({"Missing Values": miss, "Percentage(%)": percentage_miss})

    return missing


missing_values(df)
# Out:
#                    Missing Values  Percentage(%)
# ChgOffDate                 736465       0.819055
# RevLineCr                    4528       0.005036
# LowDoc                       2582       0.002872
# DisbursementDate             2368       0.002634
# MIS_Status                   1997       0.002221
# BankState                    1566       0.001742
# Bank                         1559       0.001734
# NewExist                      136       0.000151
# City                           30       0.000033
# State                          14       0.000016
# Name                           14       0.000016
# LoanNr_ChkDgt                   0       0.000000
# GrAppv                          0       0.000000
# ChgOffPrinGr                    0       0.000000
# BalanceGross                    0       0.000000
# DisbursementGross               0       0.000000
# CreateJob                       0       0.000000
# UrbanRural                      0       0.000000
# FranchiseCode                   0       0.000000
# RetainedJob                     0       0.000000
# NoEmp                           0       0.000000
# Term                            0       0.000000
# ApprovalFY                      0       0.000000
# ApprovalDate                    0       0.000000
# NAICS                           0       0.000000
# Zip                             0       0.000000
# SBA_Appv                        0       0.000000

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# We drop the column ```ChgOffDate```, representing the **date when a loan is declared to be in default**, due to the high percentage of missing values.

# %%
#dropping the ChgOffDate column
df.drop('ChgOffDate', axis = 1, inplace=True)

# %%
# checking the unique values in the target variable
df['MIS_Status'].unique()
# Out:
# array(['P I F', 'CHGOFF', nan], dtype=object)

# %%
#checking the percentage of data retained if we choose to drop all rows with missing values 
len(df.dropna())/len(df)
# Out:
# 0.9856266487537313

# %% [markdown]
# Since we still have a very significant amount of data(```98.5%```) retained after dropping the missing values, we proceed and drop them.

# %%
#dropping the rows with missing values
df.dropna(inplace=True)

# %%
#confirming that we have dropped all rows with missing values
df.isnull().sum()
# Out:
# LoanNr_ChkDgt        0
# Name                 0
# City                 0
# State                0
# Zip                  0
# Bank                 0
# BankState            0
# NAICS                0
# ApprovalDate         0
# ApprovalFY           0
# Term                 0
# NoEmp                0
# NewExist             0
# CreateJob            0
# RetainedJob          0
# FranchiseCode        0
# UrbanRural           0
# RevLineCr            0
# LowDoc               0
# DisbursementDate     0
# DisbursementGross    0
# BalanceGross         0
# MIS_Status           0
# ChgOffPrinGr         0
# GrAppv               0
# SBA_Appv             0
# dtype: int64

# %% [markdown]
# Next, we remove the dollar signs to facilitate data manipulation and for consistency.

# %%
#removing the dollar signs in the currency columns
dollar_columns = ['DisbursementGross', 'BalanceGross', 'ChgOffPrinGr', 'GrAppv', 'SBA_Appv']
df[dollar_columns] = df[dollar_columns].replace('[\$,]', '', regex=True).astype(float)

# %%
date_columns=['ApprovalDate','DisbursementDate']
for column in date_columns:
    df[column]=pd.to_datetime(df[column])

# %%
df[df.DisbursementDate<df.ApprovalDate]
# Out:
#         LoanNr_ChkDgt                            Name             City State  \
# 481        1003703008    AQUA BELLA ENTERPRISES, INC.          CHICAGO    IL
# 1548       1010634005             EARL'S MACHINE SHOP           ROGERS    AR
# 1655       1011204007       MACHINE SHOP SERVICES INC           NEENAH    WI
# 6907       1047134001                  ADVANTAGE ASIA         NEW YORK    NY
# 13804      1098814004            LANSING CONSTRUCTION  MONTEZUMZ CREEK    UT
# ...               ...                             ...              ...   ...
# 896648     9939483007             AUTO AUCTION DIRECT    AMERICAN FORK    UT
# 896854     9944333002  MADDEN PRINTING/MINUTEMAN PRES         FISHKILL    NY
# 897223     9952913010                      RODCO, INC      CENTERVILLE    UT
# 898373     9978813002            CROWN JEWELERS, LTD.         STAUNTON    VA
# 899107     9994623004                  MAILFAST, INC.       BIRMINGHAM    AL
#
#           Zip                            Bank BankState   NAICS ApprovalDate  \
# 481     60634            NORTH COMMUNITY BANK        IL       0   1980-06-25
# 1548    72756                      IBERIABANK        AR  332312   1997-03-05
# 1655    54956       AMER NATL BANK-FOX CITIES        WI  333512   1997-03-05
# 6907    10028  JPMORGAN CHASE BANK NATL ASSOC        IL       0   1997-03-19
# 13804   84510   VECTRA BK COLORADO NATL ASSOC        NM  235930   1997-04-04
# ...       ...                             ...       ...     ...          ...
# 896648  84003           1ST NATL BK OF LAYTON        UT  441120   1997-02-03
# 896854  12524  PNC BANK, NATIONAL ASSOCIATION        NJ       0   1997-02-05
# 897223  84014           1ST NATL BK OF LAYTON        UT  233210   1997-02-10
# 898373  24401         UNION FIRST MARKET BANK        VA  448310   1997-02-21
# 899107  35222                    COMPASS BANK        AL       0   2001-03-26
#
#        ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 481          1980    87     20       1.0          0            0
# 1548         1997    96      1       2.0          0            0
# 1655         1997    72      4       1.0          0            0
# 6907         1997   181      1       1.0          0            0
# 13804        1997    46     16       1.0          0            0
# ...           ...   ...    ...       ...        ...          ...
# 896648       1997    35      1       2.0          0            0
# 896854       1997   121      3       2.0          0            0
# 897223       1997   190      4       2.0          0            0
# 898373       1997   299      1       1.0          0            0
# 899107       2001    84     21       1.0          0            0
#
#         FranchiseCode  UrbanRural RevLineCr LowDoc DisbursementDate  \
# 481                 0           0         N      N       1980-05-12
# 1548                1           0         N      Y       1997-02-28
# 1655                1           0         N      Y       1997-02-28
# 6907                1           0         N      N       1997-02-14
# 13804               1           0         N      Y       1996-07-04
# ...               ...         ...       ...    ...              ...
# 896648              1           0         N      N       1996-04-07
# 896854              1           0         N      N       1996-10-29
# 897223              1           0         N      N       1996-04-13
# 898373              1           0         N      N       1987-04-01
# 899107              1           0         N      N       1998-01-31
#
#         DisbursementGross  BalanceGross MIS_Status  ChgOffPrinGr    GrAppv  \
# 481              350000.0           0.0     CHGOFF      311636.0  350000.0
# 1548              56400.0           0.0      P I F           0.0   56400.0
# 1655              27000.0           0.0      P I F           0.0   27000.0
# 6907              75000.0           0.0      P I F           0.0   75000.0
# 13804             40600.0           0.0      P I F           0.0   40600.0
# ...                   ...           ...        ...           ...       ...
# 896648           125000.0           0.0     CHGOFF      118002.0  125000.0
# 896854            90000.0           0.0      P I F           0.0   90000.0
# 897223           180000.0           0.0      P I F           0.0  180000.0
# 898373            50000.0           0.0      P I F           0.0   50000.0
# 899107           100000.0           0.0      P I F           0.0  100000.0
#
#         SBA_Appv
# 481     315000.0
# 1548     45120.0
# 1655     21600.0
# 6907     60000.0
# 13804    32480.0
# ...          ...
# 896648   93750.0
# 896854   72000.0
# 897223  135000.0
# 898373   37500.0
# 899107   75000.0
#
# [784 rows x 26 columns]

# %%
df = df.sort_values(by=['ApprovalDate']).reset_index(drop=True)

# %%
#confirming that all dollar signs have been dropped
df
# Out:
#         LoanNr_ChkDgt                            Name             City State  \
# 0          2357951001                    WINSLOW CORP           BERLIN    NJ
# 1          4160941004                    THE BUCKSKIN          QUEMADO    NM
# 2          3527741006                MOBICENTRICS INC            BRONX    NY
# 3          3227931002  AMERICANA INSTITUTE OF DAY CAR       GLEN ARDEN    MD
# 4          5090841007                   JAMES E SEARS          LINCOLN    NE
# ...               ...                             ...              ...   ...
# 886235     4672041009         TILLEYS ELECTRIC CO INC       BLOOMFIELD    CT
# 886236     1779841009                  MEJANS C/O SBA  KING OF PRUSSIA    PA
# 886237     4668391006         TAMBASCO SAUSAGE CO INC        AMSTERDAM    NY
# 886238     3675371004             AMERICAN CINEMA INC   SALT LAKE CITY    UT
# 886239     3525321005  SENTRY AUTOMATIC FIRE ALARM CO         NEW CITY    NY
#
#           Zip                            Bank BankState  NAICS ApprovalDate  \
# 0        8009  PNC BANK, NATIONAL ASSOCIATION        NJ      0   1973-02-06
# 1       87829                FIRST STATE BANK        NM      0   1973-02-14
# 2       10451      BANK OF AMERICA NATL ASSOC        NY      0   1973-02-23
# 3       20027      BANK OF AMERICA NATL ASSOC        VA      0   1973-02-28
# 4       68502                        THE BANK        KS      0   1973-03-07
# ...       ...                             ...       ...    ...          ...
# 886235   6002      BANK OF AMERICA NATL ASSOC        RI      0   2072-11-16
# 886236  19064  PNC BANK, NATIONAL ASSOCIATION        DE      0   2072-12-01
# 886237  12010    KEYBANK NATIONAL ASSOCIATION        NY      0   2072-12-05
# 886238  84102     WELLS FARGO BANK NATL ASSOC        SD      0   2072-12-05
# 886239  10956  JPMORGAN CHASE BANK NATL ASSOC        OH      0   2072-12-08
#
#        ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 0            1973   120      5       1.0          0            0
# 1            1973   230      2       1.0          0            0
# 2            1973   180     16       1.0          0            0
# 3            1973   120      1       2.0          0            0
# 4            1973   168      1       1.0          0            0
# ...           ...   ...    ...       ...        ...          ...
# 886235       1973   102     30       1.0          0            0
# 886236       1973    96      6       1.0          0            0
# 886237       1973    84      5       1.0          0            0
# 886238       1973   147      4       1.0          0            0
# 886239       1973   180     18       1.0          0            0
#
#         FranchiseCode  UrbanRural RevLineCr LowDoc DisbursementDate  \
# 0                   0           0         N      N       1973-02-27
# 1                   0           0         N      N       1973-06-08
# 2                   0           0         N      N       1973-03-29
# 3                   0           0         N      N       1973-04-12
# 4               17750           0         N      N       1973-03-16
# ...               ...         ...       ...    ...              ...
# 886235              0           0         N      N       2072-12-01
# 886236              0           0         N      N       1973-09-13
# 886237              0           0         N      N       2072-12-27
# 886238              0           0         N      N       1973-01-03
# 886239              0           0         N      N       1973-01-18
#
#         DisbursementGross  BalanceGross MIS_Status  ChgOffPrinGr    GrAppv  \
# 0                200000.0           0.0     CHGOFF      199955.0  200000.0
# 1                155000.0           0.0     CHGOFF       71574.0  155000.0
# 2                150000.0           0.0     CHGOFF       10471.0  150000.0
# 3                 70000.0           0.0     CHGOFF           0.0   70000.0
# 4                 18000.0           0.0     CHGOFF         175.0   18000.0
# ...                   ...           ...        ...           ...       ...
# 886235           200000.0           0.0     CHGOFF       72983.0  200000.0
# 886236            45000.0           0.0     CHGOFF       23330.0   45000.0
# 886237            20000.0           0.0     CHGOFF       19262.0   20000.0
# 886238           200000.0           0.0     CHGOFF      113859.0  200000.0
# 886239           300000.0           0.0      P I F          28.0  300000.0
#
#         SBA_Appv
# 0       180000.0
# 1       139500.0
# 2       135000.0
# 3        63000.0
# 4        16200.0
# ...          ...
# 886235  180000.0
# 886236   31500.0
# 886237   18000.0
# 886238  180000.0
# 886239  270000.0
#
# [886240 rows x 26 columns]

# %%
df.NAICS.value_counts()
# Out:
# 0         198267
# 722110     27772
# 722211     19338
# 811111     14392
# 621210     13856
#            ...
# 212210         1
# 314992         1
# 327120         1
# 313310         1
# 315280         1
# Name: NAICS, Length: 1311, dtype: int64

# %%
df.NewExist=df.NewExist.replace(0.0,np.nan)

# %%
df.NewExist=df.NewExist.backfill()

# %%
df.NewExist.isnull().sum()
# Out:
# 0

# %%
df.NewExist.value_counts()
# Out:
# 1.0    636882
# 2.0    249358
# Name: NewExist, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
df['PercentageAprroved']=(df.SBA_Appv/df.GrAppv)*100
df['PercentageAprroved']=round(df['PercentageAprroved'],1).astype(int)

# %%
df['Industry'] = df['NAICS'].astype('str').apply(lambda x: x[:2])
df['Industry'] = df['Industry'].map({
    '11': 'Ag/For/Fish/Hunt',
    '21': 'Min/Quar/Oil_Gas_ext',
    '22': 'Utilities',
    '23': 'Construction',
    '31': 'Manufacturing',
    '32': 'Manufacturing',
    '33': 'Manufacturing',
    '42': 'Wholesale_trade',
    '44': 'Retail_trade',
    '45': 'Retail_trade',
    '48': 'Trans/Ware',
    '49': 'Trans/Ware',
    '51': 'Information',
    '52': 'Finance/Insurance',
    '53': 'RE/Rental/Lease',
    '54': 'Prof/Science/Tech',
    '55': 'Mgmt_comp',
    '56': 'Admin_sup/Waste_Mgmt_Rem',
    '61': 'Educational',
    '62': 'Healthcare/Social_assist',
    '71': 'Arts/Entertain/Rec',
    '72': 'Accom/Food_serv',
    '81': 'Other_no_pub',
    '92': 'Public_Admin',
    '0': 'Other'
})

# %%
df[df['Industry'].isna()]
# Out:
# Empty DataFrame
# Columns: [LoanNr_ChkDgt, Name, City, State, Zip, Bank, BankState, NAICS, ApprovalDate, ApprovalFY, Term, NoEmp, NewExist, CreateJob, RetainedJob, FranchiseCode, UrbanRural, RevLineCr, LowDoc, DisbursementDate, DisbursementGross, BalanceGross, MIS_Status, ChgOffPrinGr, GrAppv, SBA_Appv, PercentageAprroved, Industry]
# Index: []

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **Univariate Analysis**

# %% [markdown]
# We plot a graph to show the univariate distribution of the MIS_Status.

# %%
#plotting a histogram to visualize the distribution of the MIS_Status
plt.hist(df['MIS_Status'], bins=3)
plt.xlabel('MIS_Status')
plt.ylabel('Frequency')
plt.title('Distribution of Target Variable')
plt.show()
print(df['MIS_Status'].value_counts(normalize=True))
# Out:
# P I F     0.823929
# CHGOFF    0.176071
# Name: MIS_Status, dtype: float64

# %% [markdown]
# More loans taken up were cleared fully(```82.3%```), while a smaller percentage(```17.6%```) of the loans taken up were defaulted.

# %%
# Plotting a Histogram of DisbursementGross
plt.hist(df['DisbursementGross'], bins=20)
plt.xlabel('Disbursement Gross')
plt.ylabel('Frequency')
plt.title('Distribution of Disbursement Gross')
plt.show()

# %% [markdown]
# The amounts disbursed according to the column ``DisbursementGross`` was majorly below 2 million USD.

# %% [markdown]
# Next, we plot a scatter plot for the ``LoanNr_ChkDgt`` and the ``Term`` columns.

# %%
#visualizing the loan term of the borrower using the primary key identifier
# sns.scatterplot(data=df, x='LoanNr_ChkDgt', y='Term', hue='MIS_Status')
# plt.title('Scatter Plot: LoanNr_ChkDgt vs. Term')
# plt.show()

# %% [markdown]
# <b> Observation: </b> The amount of loans that are Paid in Full & Charged Off, are irrespective of the Term Limit of the loan.

# %%
plt.figure(figsize=(12, 10))
for i, feature in enumerate(df.select_dtypes("number"), 1):
    plt.subplot(4, 4, i)
    plt.hist(df[feature], bins=20)
    plt.xlabel(feature)
plt.tight_layout()
plt.show()

# %% [markdown]
# These histogram plots illustrate the distribution of data for the numerical columns in the dataframe.
#
# Next, we will look for any outliers in the dataframe.

# %%
# Calculate the IQR
Q1 = df['DisbursementGross'].quantile(0.25)
Q3 = df['DisbursementGross'].quantile(0.75)
IQR = Q3 - Q1
# Define the lower and upper bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Filter the outliers
outliers = df[(df['DisbursementGross'] < lower_bound) | (df['DisbursementGross'] > upper_bound)]
# Print the outliers
print(outliers)
# Out:
#         LoanNr_ChkDgt                            Name            City State  \
# 158        8260831001  WALKER-NEER MANUFACTURING CO.,   WICHITA FALLS    TX
# 229        8455081001     BECKER ELECTRONICS MFG CORP     EAST DURHAM    NY
# 243        8534501005               LUCID LINES, INC.     LOS ANGELES    CA
# 256        8420021005    CALDWELL PORT ELEVATOR, INC.        COLUMBIA    LA
# 297        8926061003           EVA DAWN NURSING HOME  SALT LAKE CITY    UT
# ...               ...                             ...             ...   ...
# 886101     6699115000  Argos Global Partner Services,    Key Biscayne    FL
# 886109     6708075004        SCA Pharmaceuticals, LLC     LITTLE ROCK    AR
# 886119     6724455000  D & D Mulch and Landscape, Inc      Bellingham    MA
# 886132     6765475002           WATERPROOF DRUG, INC.        FERRIDAY    LA
# 886141     6812465003  Holmes Property Investments, L        Magnolia    TX
#
#           Zip                            Bank BankState   NAICS ApprovalDate  \
# 158     76307      BANK OF AMERICA NATL ASSOC        TX       0   1976-07-29
# 229     12423  JPMORGAN CHASE BANK NATL ASSOC        OH       0   1977-03-25
# 243     90034              CITY NATIONAL BANK        CA       0   1977-04-26
# 256     71418            FDIC/2529 BANK DIXIE        LA       0   1977-05-16
# 297     84103  JPMORGAN CHASE BANK NATL ASSOC        AZ       0   1977-09-27
# ...       ...                             ...       ...     ...          ...
# 886101  33149                  CITIBANK, N.A.        SD  423120   2014-02-27
# 886109  72205    ARKANSAS CAPITAL CORPORATION        AR  424210   2014-03-05
# 886119   2019              CHARLES RIVER BANK        MA  561730   2014-03-14
# 886132  71334            FIRST FINANCIAL BANK        AR  446110   2014-04-07
# 886141  77354     WELLS FARGO BANK NATL ASSOC        SD  451110   2014-05-05
#
#        ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 158         1976A   174    110       1.0          0            0
# 229          1977   120    194       1.0          0            0
# 243          1977    84    200       1.0          0            0
# 256          1977   120      5       1.0          0            0
# 297          1977   110     12       1.0          0            0
# ...           ...   ...    ...       ...        ...          ...
# 886101       2014    12     14       1.0          2           14
# 886109       2014   120     21       1.0         14           21
# 886119       2014   120     43       1.0          4           43
# 886132       2014   120     14       1.0          0           14
# 886141       2014   300     35       1.0         35            0
#
#         FranchiseCode  UrbanRural RevLineCr LowDoc DisbursementDate  \
# 158                 0           0         N      N       1977-01-28
# 229                 0           0         N      N       1977-06-03
# 243                 0           0         N      N       1977-07-22
# 256                 0           0         N      N       1978-05-31
# 297                 0           0         N      N       1978-01-10
# ...               ...         ...       ...    ...              ...
# 886101              0           2         Y      N       2014-02-27
# 886109              0           1         N      N       2014-04-01
# 886119              0           1         N      N       2014-03-14
# 886132              0           2         N      N       2014-04-07
# 886141              0           1         N      N       2014-05-05
#
#         DisbursementGross  BalanceGross MIS_Status  ChgOffPrinGr     GrAppv  \
# 158              650000.0           0.0     CHGOFF      253484.0   750000.0
# 229              550000.0           0.0     CHGOFF           0.0   550000.0
# 243              550000.0           0.0     CHGOFF      317147.0   550000.0
# 256              555000.0           0.0     CHGOFF      439164.0   555000.0
# 297              555000.0           0.0     CHGOFF      262833.0   555000.0
# ...                   ...           ...        ...           ...        ...
# 886101          3000000.0           0.0      P I F           0.0  3000000.0
# 886109          2800000.0           0.0      P I F           0.0  2800000.0
# 886119          1250000.0           0.0      P I F           0.0  1250000.0
# 886132          1185000.0           0.0      P I F           0.0  1185000.0
# 886141           637200.0           0.0      P I F           0.0   637200.0
#
#          SBA_Appv  PercentageAprroved                  Industry
# 158      499500.0                  66                     Other
# 229      495000.0                  90                     Other
# 243      495000.0                  90                     Other
# 256      444000.0                  80                     Other
# 297      499500.0                  90                     Other
# ...           ...                 ...                       ...
# 886101  2700000.0                  90           Wholesale_trade
# 886109  2100000.0                  75           Wholesale_trade
# 886119   937500.0                  75  Admin_sup/Waste_Mgmt_Rem
# 886132   888750.0                  75              Retail_trade
# 886141   477900.0                  75              Retail_trade
#
# [82542 rows x 28 columns]

# %%
# # Select the relevant columns for analysis
# selected_columns = ['LoanNr_ChkDgt', 'City', 'State', 'Zip', 'Bank', 'NAICS',
#                     'RevLineCr', 'LowDoc', 'DisbursementGross', 'MIS_Status']
# # Subset the DataFrame with selected columns
# subset_df = df[selected_columns]

# # Perform bivariate analysis
# sns.set(style="ticks")
# sns.pairplot(subset_df, hue='MIS_Status')
# plt.show()

# %% [markdown]
# ### Multivariate Analysis
#
# 1. Correlation Matrix

# %%
# Create a new DataFrame for encoded variables
# Perform label encoding on each categorical column
encoded_df=pd.DataFrame()
for column in df.columns:
    if df[column].dtype == 'object':
        encoded_df[column] = df[column].astype('category').cat.codes
    else:
        encoded_df[column] = df[column]

# Calculate the correlation matrix
correlation_matrix = encoded_df.corr()

# Plot the correlation matrix using a heatmap

plt.figure(figsize=(27, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# * From the matrix, it is clear that the higher the job creation the higher the retention rate since the two have a correlation of ```99%```.
# *

# %% [markdown]
# ***SBA data, many of the categorical variables, such as state, city, and bank, have no inherent order and there are many categories. Using label encoding
# on these variables could potentially introduce unintended patterns or biases in the data, as there is no relationship or hierarchy between the categories.***
#
# ***We performed label encoding to transform the categorical variables into numerical to enable visualization on a heatmap.
# Mention the variables that have a high correlation, which ones should be dropped and why.
# Observe the accuracy level of the SBA_Approv vs GrAPPV VIS A VIS our accuracy level/target accuracy.***

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ### Feature Selection

# %%
relevant_columns=['GrAppv', 'Term', 'NoEmp','NewExist', 'UrbanRural', 'Industry','MIS_Status']
relevant_df=df.loc[:,relevant_columns]
relevant_df
# Out:
#           GrAppv  Term  NoEmp  NewExist  UrbanRural Industry MIS_Status
# 0       200000.0   120      5       1.0           0    Other     CHGOFF
# 1       155000.0   230      2       1.0           0    Other     CHGOFF
# 2       150000.0   180     16       1.0           0    Other     CHGOFF
# 3        70000.0   120      1       2.0           0    Other     CHGOFF
# 4        18000.0   168      1       1.0           0    Other     CHGOFF
# ...          ...   ...    ...       ...         ...      ...        ...
# 886235  200000.0   102     30       1.0           0    Other     CHGOFF
# 886236   45000.0    96      6       1.0           0    Other     CHGOFF
# 886237   20000.0    84      5       1.0           0    Other     CHGOFF
# 886238  200000.0   147      4       1.0           0    Other     CHGOFF
# 886239  300000.0   180     18       1.0           0    Other      P I F
#
# [886240 rows x 7 columns]

# %% [markdown]
# ### Encoding

# %%
encoded_df=pd.DataFrame()
for column in relevant_df.columns:
    if relevant_df[column].dtype == 'object':
        encoded_df[column] = relevant_df[column].astype('category').cat.codes
    else:
        encoded_df[column] = relevant_df[column]

# %%
encoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886240 entries, 0 to 886239
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   GrAppv      886240 non-null  float64
#  1   Term        886240 non-null  int64
#  2   NoEmp       886240 non-null  int64
#  3   NewExist    886240 non-null  float64
#  4   UrbanRural  886240 non-null  int64
#  5   Industry    886240 non-null  int8
#  6   MIS_Status  886240 non-null  int8
# dtypes: float64(2), int64(3), int8(2)
# memory usage: 35.5 MB

# %%
encoded_df
# Out:
#           GrAppv  Term  NoEmp  NewExist  UrbanRural  Industry  MIS_Status
# 0       200000.0   120      5       1.0           0        12           0
# 1       155000.0   230      2       1.0           0        12           0
# 2       150000.0   180     16       1.0           0        12           0
# 3        70000.0   120      1       2.0           0        12           0
# 4        18000.0   168      1       1.0           0        12           0
# ...          ...   ...    ...       ...         ...       ...         ...
# 886235  200000.0   102     30       1.0           0        12           0
# 886236   45000.0    96      6       1.0           0        12           0
# 886237   20000.0    84      5       1.0           0        12           0
# 886238  200000.0   147      4       1.0           0        12           0
# 886239  300000.0   180     18       1.0           0        12           1
#
# [886240 rows x 7 columns]

# %%
# Calculate the correlation matrix
correlation_matrix = encoded_df.corr()

# Plot the correlation matrix using a heatmap

plt.figure(figsize=(27, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Train Test Split

# %%
X=encoded_df.drop('MIS_Status',axis=1)
y=encoded_df['MIS_Status']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %% [markdown]
# ### Resampling

# %%
from imblearn.over_sampling import RandomOverSampler
sampler=RandomOverSampler(sampling_strategy='minority')
X_train, y_train = sampler.fit_resample(X_train,y_train)

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: MIS_Status, dtype: float64

# %%
y_train.iloc[886239]
# Out:
# 0

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
y_train_df=pd.DataFrame(y_train,columns=['MIS_Status'])
train_data=pd.concat([X_train,y_train_df],axis=1)
scaler.fit(train_data)
scaled_train_data=pd.DataFrame(scaler.transform(train_data),columns=relevant_columns)
scaled_train_data
# Out:
#            GrAppv      Term     NoEmp  NewExist  UrbanRural  Industry  \
# 0       -0.247028 -0.050931 -0.080226 -0.637000   -1.391391 -0.456671
# 1       -0.581886 -0.078305 -0.121643  1.569858    0.251784  0.384066
# 2        2.577083  1.235650 -0.025003 -0.637000    1.894959 -1.465555
# 3       -0.439475 -0.078305 -0.066420  1.569858   -1.391391 -1.129260
# 4       -0.439475  0.414428 -0.107838  1.569858    1.894959  0.552214
# ...           ...       ...       ...       ...         ...       ...
# 1168303  2.404208  2.303238  0.541032 -0.637000    0.251784  0.552214
# 1168304 -0.439475 -1.050084 -0.066420 -0.637000    0.251784 -1.129260
# 1168305 -0.593433 -1.173267  0.057831  1.569858    0.251784 -1.801849
# 1168306 -0.439475 -1.132206 -0.094032 -0.637000    0.251784 -0.288523
# 1168307 -0.535699 -0.310984 -0.121643 -0.637000    1.894959  0.384066
#
#          MIS_Status
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1168303        -1.0
# 1168304        -1.0
# 1168305        -1.0
# 1168306        -1.0
# 1168307        -1.0
#
# [1168308 rows x 7 columns]

# %%
scaled_train_data
# Out:
#            GrAppv      Term     NoEmp  NewExist  UrbanRural  Industry  \
# 0       -0.247028 -0.050931 -0.080226 -0.637000   -1.391391 -0.456671
# 1       -0.581886 -0.078305 -0.121643  1.569858    0.251784  0.384066
# 2        2.577083  1.235650 -0.025003 -0.637000    1.894959 -1.465555
# 3       -0.439475 -0.078305 -0.066420  1.569858   -1.391391 -1.129260
# 4       -0.439475  0.414428 -0.107838  1.569858    1.894959  0.552214
# ...           ...       ...       ...       ...         ...       ...
# 1168303  2.404208  2.303238  0.541032 -0.637000    0.251784  0.552214
# 1168304 -0.439475 -1.050084 -0.066420 -0.637000    0.251784 -1.129260
# 1168305 -0.593433 -1.173267  0.057831  1.569858    0.251784 -1.801849
# 1168306 -0.439475 -1.132206 -0.094032 -0.637000    0.251784 -0.288523
# 1168307 -0.535699 -0.310984 -0.121643 -0.637000    1.894959  0.384066
#
#          MIS_Status
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1168303        -1.0
# 1168304        -1.0
# 1168305        -1.0
# 1168306        -1.0
# 1168307        -1.0
#
# [1168308 rows x 7 columns]

# %%
y_test_df=pd.DataFrame(y_test,columns=['MIS_Status'])
test_data = pd.concat([X_test,y_test_df],axis=1)
scaled_test_data=pd.DataFrame(scaler.transform(test_data),columns=relevant_columns)
scaled_test_data
# Out:
#           GrAppv      Term     NoEmp  NewExist  UrbanRural  Industry  \
# 0      -0.223934 -0.215175 -0.080226  1.569858    0.251784  0.384066
# 1      -0.343252 -0.406793 -0.094032 -0.637000    0.251784 -0.288523
# 2      -0.535699 -0.105679 -0.038809 -0.637000    0.251784 -0.624818
# 3       0.522762 -0.653160 -0.080226 -0.637000    0.251784  0.384066
# 4      -0.041879  0.414428 -0.094032 -0.637000    1.894959  0.384066
# ...          ...       ...       ...       ...         ...       ...
# 177243 -0.535699 -0.571038 -0.066420 -0.637000    0.251784 -0.288523
# 177244 -0.593433 -1.022709 -0.121643  1.569858    0.251784 -1.129260
# 177245 -0.554944 -0.735282 -0.080226 -0.637000    0.251784  1.561098
# 177246  2.358709  2.056872  0.002608 -0.637000    1.894959  0.552214
# 177247 -0.612678 -0.078305 -0.121643  1.569858    0.251784  0.552214
#
#         MIS_Status
# 0             -1.0
# 1              1.0
# 2              1.0
# 3             -1.0
# 4              1.0
# ...            ...
# 177243         1.0
# 177244        -1.0
# 177245        -1.0
# 177246         1.0
# 177247         1.0
#
# [177248 rows x 7 columns]

# %% [markdown]
# ### Reformating

# %%
scaled_X_train=scaled_train_data.drop('MIS_Status',axis=1)
scaled_y_train=scaled_train_data['MIS_Status']
scaled_X_test=scaled_test_data.drop('MIS_Status',axis=1)
scaled_y_test=scaled_test_data['MIS_Status']

# %% [markdown]
# ### Modeling

# %%
scaled_y_train.value_counts(normalize=True)
# Out:
#  1.0    0.5
# -1.0    0.5
# Name: MIS_Status, dtype: float64

# %% [markdown]
# This is a binary classification task

# %% [markdown]
# **Suitable Models**
#
# `logistic regression`
#
# `decision tree`
#
# `random forest`
#
# `support vector machine`
#
# `neural network`

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
clf=LogisticRegression()
clf.fit(scaled_X_train,y_train)
preds=clf.predict(scaled_X_test)
accuracy_score(preds,y_test)
# Out:
# 0.7426035836793645

# %% [markdown]
# ### Neural Network

# %%
print(scaled_X_train.shape)
print(scaled_y_train.shape)
# Out:
# (1168308, 6)
# (1168308,)

# %%
# 5 layers sequential dropping
from keras.models import Sequential
from keras.layers import Dense,Flatten

model = Sequential()
model.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model.add(Dense(128, activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(scaled_X_train, y_train, epochs=12, batch_size=32, validation_split=0.1)

# Make binary predictions on the test data
y_pred = model.predict(scaled_X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
# Out:
# Epoch 1/12
# 32859/32859 [==============================] - 72s 2ms/step - loss: 0.3891 - accuracy: 0.8389 - val_loss: 0.4105 - val_accuracy: 0.8385
# Epoch 2/12
# 32859/32859 [==============================] - 66s 2ms/step - loss: 0.3403 - accuracy: 0.8636 - val_loss: 0.3681 - val_accuracy: 0.8690
# Epoch 3/12
# 32859/32859 [==============================] - 70s 2ms/step - loss: 0.3211 - accuracy: 0.8692 - val_loss: 0.3797 - val_accuracy: 0.8562
# Epoch 4/12
# 32859/32859 [==============================] - 69s 2ms/step - loss: 0.3067 - accuracy: 0.8729 - val_loss: 0.3037 - val_accuracy: 0.8830
# Epoch 5/12
# 32859/32859 [==============================] - 74s 2ms/step - loss: 0.2997 - accuracy: 0.8755 - val_loss: 0.3772 - val_accuracy: 0.8457
# Epoch 6/12
# 32859/32859 [==============================] - 69s 2ms/step - loss: 0.2964 - accuracy: 0.8770 - val_loss: 0.4011 - val_accuracy: 0.8366
# Epoch 7/12
# 32859/32859 [==============================] - 70s 2ms/step - loss: 0.2919 - accuracy: 0.8788 - val_loss: 0.3680 - val_accuracy: 0.8516
# Epoch 8/12
# 32859/32859 [==============================] - 70s 2ms/step - loss: 0.2897 - accuracy: 0.8794 - val_loss: 0.3501 - val_accuracy: 0.8477
# Epoch 9/12
# 32859/32859 [==============================] - 72s 2ms/step - loss: 0.2880 - accuracy: 0.8800 - val_loss: 0.2994 - val_accuracy: 0.8797
# Epoch 10/12
# 32859/32859 [==============================] - 73s 2ms/step - loss: 0.2858 - accuracy: 0.8814 - val_loss: 0.3395 - val_accuracy: 0.8589
# Epoch 11/12
# 32859/32859 [==============================] - 67s 2ms/step - loss: 0.2845 - accuracy: 0.8819 - val_loss: 0.3219 - val_accuracy: 0.8720
# Epoch 12/12
# 32859/32859 [==============================] - 70s 2ms/step - loss: 0.2835 - accuracy: 0.8821 - val_loss: 0.3539 - val_accuracy: 0.8531
# 5539/5539 [==============================] - 7s 1ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_binary,y_test)
# Out:
# 0.8873612114100018

# %%
# 6 layers sequential dropping
model2 = Sequential()
model2.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model2.add(Dense(128, activation='relu'))
model2.add(Dense(64,activation='relu'))
model2.add(Dense(32,activation='relu'))
model2.add(Dense(16,activation='relu'))
model2.add(Dense(8,activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

model2.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model2.fit(scaled_X_train, y_train, epochs=12, batch_size=32, validation_split=0.1)

# Make binary predictions on the test data
y_pred2 = model2.predict(scaled_X_test)
y_pred_binary2 = (y_pred2 > 0.5).astype(int)
# Out:
# Epoch 1/12
# 32859/32859 [==============================] - 87s 3ms/step - loss: 0.3865 - accuracy: 0.8396 - val_loss: 0.3300 - val_accuracy: 0.8766
# Epoch 2/12
# 32859/32859 [==============================] - 108s 3ms/step - loss: 0.3469 - accuracy: 0.8607 - val_loss: 0.3920 - val_accuracy: 0.8692
# Epoch 3/12
# 32859/32859 [==============================] - 106s 3ms/step - loss: 0.3301 - accuracy: 0.8675 - val_loss: 0.3684 - val_accuracy: 0.8683
# Epoch 4/12
# 32859/32859 [==============================] - 74s 2ms/step - loss: 0.3154 - accuracy: 0.8705 - val_loss: 0.3872 - val_accuracy: 0.8486
# Epoch 5/12
# 32859/32859 [==============================] - 72s 2ms/step - loss: 0.3069 - accuracy: 0.8732 - val_loss: 0.3353 - val_accuracy: 0.8786
# Epoch 6/12
# 32859/32859 [==============================] - 74s 2ms/step - loss: 0.3014 - accuracy: 0.8753 - val_loss: 0.3223 - val_accuracy: 0.8748
# Epoch 7/12
# 32859/32859 [==============================] - 74s 2ms/step - loss: 0.2947 - accuracy: 0.8779 - val_loss: 0.2909 - val_accuracy: 0.8983
# Epoch 8/12
# 32859/32859 [==============================] - 75s 2ms/step - loss: 0.2913 - accuracy: 0.8796 - val_loss: 0.3374 - val_accuracy: 0.8614
# Epoch 9/12
# 32859/32859 [==============================] - 89s 3ms/step - loss: 0.2880 - accuracy: 0.8806 - val_loss: 0.3415 - val_accuracy: 0.8565
# Epoch 10/12
# 32859/32859 [==============================] - 83s 3ms/step - loss: 0.2853 - accuracy: 0.8815 - val_loss: 0.3271 - val_accuracy: 0.8611
# Epoch 11/12
# 32859/32859 [==============================] - 66s 2ms/step - loss: 0.2832 - accuracy: 0.8822 - val_loss: 0.3154 - val_accuracy: 0.8623
# Epoch 12/12
# 32859/32859 [==============================] - 68s 2ms/step - loss: 0.2815 - accuracy: 0.8827 - val_loss: 0.3176 - val_accuracy: 0.8639
# 5539/5539 [==============================] - 7s 1ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_binary2,y_test)
# Out:
# 0.8970764127098755

# %%
# 5 layers non-sequential dropping
model3 = Sequential()
model3.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model3.add(Dense(128, activation='relu'))
model3.add(Dense(64,activation='relu'))
model3.add(Dense(32,activation='relu'))
model3.add(Dense(64,activation='relu'))
model3.add(Dense(1, activation='sigmoid'))

model3.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model3.fit(scaled_X_train, y_train, epochs=12, batch_size=32, validation_split=0.1)

# Make binary predictions on the test data
y_pred3 = model3.predict(scaled_X_test)
y_pred_binary3 = (y_pred3 > 0.5).astype(int)
# Out:
# Epoch 1/12
# 32859/32859 [==============================] - 62s 2ms/step - loss: 0.3789 - accuracy: 0.8437 - val_loss: 0.4217 - val_accuracy: 0.8395
# Epoch 2/12
# 32859/32859 [==============================] - 108s 3ms/step - loss: 0.3422 - accuracy: 0.8629 - val_loss: 0.3560 - val_accuracy: 0.8632
# Epoch 3/12
# 32859/32859 [==============================] - 75s 2ms/step - loss: 0.3265 - accuracy: 0.8679 - val_loss: 0.3119 - val_accuracy: 0.8726
# Epoch 4/12
# 32859/32859 [==============================] - 69s 2ms/step - loss: 0.3167 - accuracy: 0.8705 - val_loss: 0.3723 - val_accuracy: 0.8524
# Epoch 5/12
# 32859/32859 [==============================] - 81s 2ms/step - loss: 0.3105 - accuracy: 0.8734 - val_loss: 0.3815 - val_accuracy: 0.8569
# Epoch 6/12
# 32859/32859 [==============================] - 63s 2ms/step - loss: 0.3006 - accuracy: 0.8759 - val_loss: 0.3460 - val_accuracy: 0.8681
# Epoch 7/12
# 32859/32859 [==============================] - 64s 2ms/step - loss: 0.2940 - accuracy: 0.8779 - val_loss: 0.3095 - val_accuracy: 0.8798
# Epoch 8/12
# 32859/32859 [==============================] - 68s 2ms/step - loss: 0.2903 - accuracy: 0.8800 - val_loss: 0.3072 - val_accuracy: 0.8775
# Epoch 9/12
# 32859/32859 [==============================] - 65s 2ms/step - loss: 0.2882 - accuracy: 0.8811 - val_loss: 0.3294 - val_accuracy: 0.8638
# Epoch 10/12
# 32859/32859 [==============================] - 69s 2ms/step - loss: 0.2863 - accuracy: 0.8822 - val_loss: 0.3348 - val_accuracy: 0.8668
# Epoch 11/12
# 32859/32859 [==============================] - 65s 2ms/step - loss: 0.2847 - accuracy: 0.8828 - val_loss: 0.3221 - val_accuracy: 0.8768
# Epoch 12/12
# 32859/32859 [==============================] - 63s 2ms/step - loss: 0.2832 - accuracy: 0.8837 - val_loss: 0.3659 - val_accuracy: 0.8433
# 5539/5539 [==============================] - 7s 1ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_binary3,y_test)
# Out:
# 0.887496614912439

# %%
# 6 layers non-sequential dropping
model4 = Sequential()
model4.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model4.add(Dense(128, activation='relu'))
model4.add(Dense(64,activation='relu'))
model4.add(Dense(32,activation='relu'))
model4.add(Dense(64,activation='relu'))
model4.add(Dense(32,activation='relu'))
model4.add(Dense(1, activation='sigmoid'))

model4.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model4.fit(scaled_X_train, y_train, epochs=20, batch_size=20, validation_split=0.1)

# Make binary predictions on the test data
y_pred4 = model4.predict(scaled_X_test)
y_pred_binary4 = (y_pred4 > 0.5).astype(int)
# Out:
# Epoch 1/20
# 52574/52574 [==============================] - 257s 5ms/step - loss: 0.3784 - accuracy: 0.8436 - val_loss: 0.3668 - val_accuracy: 0.8560
# Epoch 2/20
# 52574/52574 [==============================] - 265s 5ms/step - loss: 0.3391 - accuracy: 0.8619 - val_loss: 0.3898 - val_accuracy: 0.8426
# Epoch 3/20
# 52574/52574 [==============================] - 261s 5ms/step - loss: 0.3143 - accuracy: 0.8710 - val_loss: 0.3413 - val_accuracy: 0.8772
# Epoch 4/20
# 52574/52574 [==============================] - 253s 5ms/step - loss: 0.2988 - accuracy: 0.8756 - val_loss: 0.3565 - val_accuracy: 0.8565
# Epoch 5/20
# 52574/52574 [==============================] - 238s 5ms/step - loss: 0.2940 - accuracy: 0.8777 - val_loss: 0.3211 - val_accuracy: 0.8642
# Epoch 6/20
# 52574/52574 [==============================] - 212s 4ms/step - loss: 0.2910 - accuracy: 0.8791 - val_loss: 0.3396 - val_accuracy: 0.8488
# Epoch 7/20
# 52574/52574 [==============================] - 239s 5ms/step - loss: 0.2885 - accuracy: 0.8801 - val_loss: 0.3266 - val_accuracy: 0.8555
# Epoch 8/20
# 52574/52574 [==============================] - 242s 5ms/step - loss: 0.2859 - accuracy: 0.8816 - val_loss: 0.3412 - val_accuracy: 0.8591
# Epoch 9/20
# 52574/52574 [==============================] - 241s 5ms/step - loss: 0.2849 - accuracy: 0.8822 - val_loss: 0.2992 - val_accuracy: 0.8826
# Epoch 10/20
# 52574/52574 [==============================] - 229s 4ms/step - loss: 0.2836 - accuracy: 0.8830 - val_loss: 0.3149 - val_accuracy: 0.8722
# Epoch 11/20
# 52574/52574 [==============================] - 238s 5ms/step - loss: 0.2816 - accuracy: 0.8836 - val_loss: 0.3063 - val_accuracy: 0.8650
# Epoch 12/20
# 52574/52574 [==============================] - 209s 4ms/step - loss: 0.2810 - accuracy: 0.8842 - val_loss: 0.2961 - val_accuracy: 0.8717
# Epoch 13/20
# 52574/52574 [==============================] - 236s 4ms/step - loss: 0.2809 - accuracy: 0.8847 - val_loss: 0.3252 - val_accuracy: 0.8600
# Epoch 14/20
# 52574/52574 [==============================] - 248s 5ms/step - loss: 0.2790 - accuracy: 0.8856 - val_loss: 0.3143 - val_accuracy: 0.8569
# Epoch 15/20
# 52574/52574 [==============================] - 216s 4ms/step - loss: 0.2787 - accuracy: 0.8859 - val_loss: 0.3240 - val_accuracy: 0.8668
# Epoch 16/20
# 52574/52574 [==============================] - 231s 4ms/step - loss: 0.2773 - accuracy: 0.8861 - val_loss: 0.2959 - val_accuracy: 0.8738
# Epoch 17/20
# 52574/52574 [==============================] - 195s 4ms/step - loss: 0.2766 - accuracy: 0.8866 - val_loss: 0.3358 - val_accuracy: 0.8700
# Epoch 18/20
# 52574/52574 [==============================] - 194s 4ms/step - loss: 0.2766 - accuracy: 0.8870 - val_loss: 0.3030 - val_accuracy: 0.8750
# Epoch 19/20
# 52574/52574 [==============================] - 1625s 31ms/step - loss: 0.2756 - accuracy: 0.8873 - val_loss: 0.3248 - val_accuracy: 0.8669
# Epoch 20/20
# 52574/52574 [==============================] - 227s 4ms/step - loss: 0.2754 - accuracy: 0.8880 - val_loss: 0.3377 - val_accuracy: 0.8573
# 5539/5539 [==============================] - 17s 3ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_binary4,y_test)
# Out:
# 0.9062217909369923

# %%
# 7 layers non-sequential dropping
import tensorflow as tf
model5 = Sequential()
model5.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model5.add(Dense(324, activation='relu'))
model5.add(Dense(164,activation='relu'))
model5.add(Dense(232,activation='relu'))
model5.add(Dense(64,activation='relu'))
model5.add(Dense(32,activation='relu'))
model5.add(Dense(1, activation='sigmoid'))

model5.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model5.fit(scaled_X_train, y_train, epochs=12, batch_size=32, validation_split=0.1)

# Make binary predictions on the test data
y_pred5 = model5.predict(scaled_X_test)
y_pred_binary5 = (y_pred5 > 0.5).astype(int)
# Out:
# Epoch 1/12
# 32859/32859 [==============================] - 71s 2ms/step - loss: 0.3852 - accuracy: 0.8417 - val_loss: 0.3512 - val_accuracy: 0.8655
# Epoch 2/12
# 32859/32859 [==============================] - 76s 2ms/step - loss: 0.3448 - accuracy: 0.8619 - val_loss: 0.3649 - val_accuracy: 0.8747
# Epoch 3/12
# 32859/32859 [==============================] - 70s 2ms/step - loss: 0.3270 - accuracy: 0.8673 - val_loss: 0.3452 - val_accuracy: 0.8585
# Epoch 4/12
# 32859/32859 [==============================] - 69s 2ms/step - loss: 0.3172 - accuracy: 0.8707 - val_loss: 0.3686 - val_accuracy: 0.8571
# Epoch 5/12
# 32859/32859 [==============================] - 69s 2ms/step - loss: 0.3031 - accuracy: 0.8743 - val_loss: 0.3530 - val_accuracy: 0.8552
# Epoch 6/12
# 32859/32859 [==============================] - 85s 3ms/step - loss: 0.2968 - accuracy: 0.8768 - val_loss: 0.3214 - val_accuracy: 0.8575
# Epoch 7/12
# 32859/32859 [==============================] - 118s 4ms/step - loss: 0.2924 - accuracy: 0.8784 - val_loss: 0.3397 - val_accuracy: 0.8577
# Epoch 8/12
# 32859/32859 [==============================] - 112s 3ms/step - loss: 0.2882 - accuracy: 0.8798 - val_loss: 0.3182 - val_accuracy: 0.8768
# Epoch 9/12
# 32859/32859 [==============================] - 905s 28ms/step - loss: 0.2858 - accuracy: 0.8809 - val_loss: 0.3418 - val_accuracy: 0.8531
# Epoch 10/12
# 32859/32859 [==============================] - 74s 2ms/step - loss: 0.2836 - accuracy: 0.8819 - val_loss: 0.3302 - val_accuracy: 0.8687
# Epoch 11/12
# 32859/32859 [==============================] - 69s 2ms/step - loss: 0.2824 - accuracy: 0.8825 - val_loss: 0.3435 - val_accuracy: 0.8491
# Epoch 12/12
# 32859/32859 [==============================] - 73s 2ms/step - loss: 0.2805 - accuracy: 0.8837 - val_loss: 0.3109 - val_accuracy: 0.8717
# 5539/5539 [==============================] - 8s 1ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_binary5,y_test)
# Out:
# 0.8952823163025817

# %%
# Pump up number of neurons
model6 = Sequential()
model6.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model6.add(Dense(328, activation='relu'))
model6.add(Dense(128,activation='relu'))
model6.add(Dense(64,activation='relu'))
model6.add(Dense(128,activation='relu'))
model6.add(Dense(1, activation='sigmoid'))
K.set_value(model.optimizer.learning_rate, 0.001)
model6.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model6.fit(scaled_X_train, y_train, epochs=40, batch_size=20, validation_split=0.1)

# Make binary predictions on the test data
y_pred6 = model6.predict(scaled_X_test)
y_pred_binary6 = (y_pred6 > 0.5).astype(int)
# Out:
# Epoch 1/40
# 52574/52574 [==============================] - 310s 6ms/step - loss: 0.3780 - accuracy: 0.8444 - val_loss: 0.4205 - val_accuracy: 0.8370
# Epoch 2/40
# 52574/52574 [==============================] - 303s 6ms/step - loss: 0.3389 - accuracy: 0.8623 - val_loss: 0.3908 - val_accuracy: 0.8632
# Epoch 3/40
# 52574/52574 [==============================] - 293s 6ms/step - loss: 0.3229 - accuracy: 0.8684 - val_loss: 0.3801 - val_accuracy: 0.8375
# Epoch 4/40
# 52574/52574 [==============================] - 295s 6ms/step - loss: 0.3081 - accuracy: 0.8725 - val_loss: 0.3347 - val_accuracy: 0.8668
# Epoch 5/40
# 52574/52574 [==============================] - 355s 7ms/step - loss: 0.2972 - accuracy: 0.8758 - val_loss: 0.3544 - val_accuracy: 0.8553
# Epoch 6/40
# 52574/52574 [==============================] - 355s 7ms/step - loss: 0.2926 - accuracy: 0.8781 - val_loss: 0.3375 - val_accuracy: 0.8640
# Epoch 7/40
# 52574/52574 [==============================] - 355s 7ms/step - loss: 0.2897 - accuracy: 0.8792 - val_loss: 0.3397 - val_accuracy: 0.8601
# Epoch 8/40
# 52574/52574 [==============================] - 355s 7ms/step - loss: 0.2874 - accuracy: 0.8804 - val_loss: 0.3531 - val_accuracy: 0.8580
# Epoch 9/40
# 52574/52574 [==============================] - 346s 7ms/step - loss: 0.2856 - accuracy: 0.8818 - val_loss: 0.3306 - val_accuracy: 0.8622
# Epoch 10/40
# 52574/52574 [==============================] - 366s 7ms/step - loss: 0.2834 - accuracy: 0.8828 - val_loss: 0.3262 - val_accuracy: 0.8660
# Epoch 11/40
# 52574/52574 [==============================] - 357s 7ms/step - loss: 0.2822 - accuracy: 0.8836 - val_loss: 0.3558 - val_accuracy: 0.8494
# Epoch 12/40
# 52574/52574 [==============================] - 359s 7ms/step - loss: 0.2810 - accuracy: 0.8841 - val_loss: 0.3159 - val_accuracy: 0.8672
# Epoch 13/40
# 52574/52574 [==============================] - 361s 7ms/step - loss: 0.2797 - accuracy: 0.8848 - val_loss: 0.2973 - val_accuracy: 0.8751
# Epoch 14/40
# 52574/52574 [==============================] - 357s 7ms/step - loss: 0.2785 - accuracy: 0.8851 - val_loss: 0.2978 - val_accuracy: 0.8766
# Epoch 15/40
# 52574/52574 [==============================] - 359s 7ms/step - loss: 0.2779 - accuracy: 0.8857 - val_loss: 0.3023 - val_accuracy: 0.8778
# Epoch 16/40
# 52574/52574 [==============================] - 351s 7ms/step - loss: 0.2773 - accuracy: 0.8857 - val_loss: 0.3207 - val_accuracy: 0.8538
# Epoch 17/40
# 52574/52574 [==============================] - 212s 4ms/step - loss: 0.2767 - accuracy: 0.8863 - val_loss: 0.3132 - val_accuracy: 0.8712
# Epoch 18/40
# 52574/52574 [==============================] - 210s 4ms/step - loss: 0.2772 - accuracy: 0.8865 - val_loss: 0.3089 - val_accuracy: 0.8669
# Epoch 19/40
# 52574/52574 [==============================] - 211s 4ms/step - loss: 0.2764 - accuracy: 0.8866 - val_loss: 0.2916 - val_accuracy: 0.8822
# Epoch 20/40
# 52574/52574 [==============================] - 211s 4ms/step - loss: 0.2761 - accuracy: 0.8866 - val_loss: 0.3049 - val_accuracy: 0.8755
# Epoch 21/40
# 52574/52574 [==============================] - 214s 4ms/step - loss: 0.2751 - accuracy: 0.8871 - val_loss: 0.2979 - val_accuracy: 0.8884
# Epoch 22/40
# 52574/52574 [==============================] - 223s 4ms/step - loss: 0.2746 - accuracy: 0.8877 - val_loss: 0.3248 - val_accuracy: 0.8681
# Epoch 23/40
# 52574/52574 [==============================] - 215s 4ms/step - loss: 0.2745 - accuracy: 0.8879 - val_loss: 0.3108 - val_accuracy: 0.8773
# Epoch 24/40
# 52574/52574 [==============================] - 213s 4ms/step - loss: 0.2741 - accuracy: 0.8881 - val_loss: 0.3092 - val_accuracy: 0.8672
# Epoch 25/40
# 52574/52574 [==============================] - 211s 4ms/step - loss: 0.2741 - accuracy: 0.8882 - val_loss: 0.3197 - val_accuracy: 0.8611
# Epoch 26/40
# 52574/52574 [==============================] - 217s 4ms/step - loss: 0.2738 - accuracy: 0.8886 - val_loss: 0.2975 - val_accuracy: 0.8747
# Epoch 27/40
# 52574/52574 [==============================] - 208s 4ms/step - loss: 0.2729 - accuracy: 0.8882 - val_loss: 0.2910 - val_accuracy: 0.8722
# Epoch 28/40
# 52574/52574 [==============================] - 200s 4ms/step - loss: 0.2734 - accuracy: 0.8886 - val_loss: 0.3082 - val_accuracy: 0.8722
# Epoch 29/40
# 52574/52574 [==============================] - 207s 4ms/step - loss: 0.2735 - accuracy: 0.8888 - val_loss: 0.3264 - val_accuracy: 0.8610
# Epoch 30/40
# 52574/52574 [==============================] - 211s 4ms/step - loss: 0.2721 - accuracy: 0.8892 - val_loss: 0.3084 - val_accuracy: 0.8636
# Epoch 31/40
# 52574/52574 [==============================] - 209s 4ms/step - loss: 0.2719 - accuracy: 0.8894 - val_loss: 0.3047 - val_accuracy: 0.8691
# Epoch 32/40
# 52574/52574 [==============================] - 202s 4ms/step - loss: 0.2723 - accuracy: 0.8890 - val_loss: 0.3255 - val_accuracy: 0.8557
# Epoch 33/40
# 52574/52574 [==============================] - 178s 3ms/step - loss: 0.2718 - accuracy: 0.8892 - val_loss: 0.3026 - val_accuracy: 0.8739
# Epoch 34/40
# 52574/52574 [==============================] - 176s 3ms/step - loss: 0.2719 - accuracy: 0.8894 - val_loss: 0.3580 - val_accuracy: 0.8540
# Epoch 35/40
# 52574/52574 [==============================] - 341s 6ms/step - loss: 0.2717 - accuracy: 0.8895 - val_loss: 0.2907 - val_accuracy: 0.8798
# Epoch 36/40
# 52574/52574 [==============================] - 222s 4ms/step - loss: 0.2782 - accuracy: 0.8895 - val_loss: 0.3031 - val_accuracy: 0.8660
# Epoch 37/40
# 52574/52574 [==============================] - 204s 4ms/step - loss: 0.2717 - accuracy: 0.8895 - val_loss: 0.3101 - val_accuracy: 0.8668
# Epoch 38/40
# 52574/52574 [==============================] - 191s 4ms/step - loss: 0.2716 - accuracy: 0.8892 - val_loss: 0.3296 - val_accuracy: 0.8601
# Epoch 39/40
# 52574/52574 [==============================] - 219s 4ms/step - loss: 0.2726 - accuracy: 0.8895 - val_loss: 0.2815 - val_accuracy: 0.8702
# Epoch 40/40
# 52574/52574 [==============================] - 217s 4ms/step - loss: 0.2768 - accuracy: 0.8894 - val_loss: 0.3436 - val_accuracy: 0.8508
# 5539/5539 [==============================] - 14s 2ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_binary6,y_test)
# Out:
# 0.9091216826141902

# %%
#Using Scaled y_train and test
model7 = Sequential()
model7.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model7.add(Dense(328, activation='relu'))
model7.add(Dense(128,activation='relu'))
model7.add(Dense(64,activation='relu'))
model7.add(Dense(128,activation='relu'))
model7.add(Dense(1, activation='sigmoid'))

model7.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model7.fit(scaled_X_train, scaled_y_train, epochs=12, batch_size=32, validation_split=0.1)

# Make binary predictions on the test data
y_pred7 = model7.predict(scaled_X_test)
y_pred_binary7 = (y_pred7 > 0.5).astype(int)
# Out:
# Epoch 1/12
# 32859/32859 [==============================] - 93s 3ms/step - loss: -58277886951424.0000 - accuracy: 0.2176 - val_loss: -1297150721916928.0000 - val_accuracy: 0.0000e+00
# Epoch 2/12
# 32859/32859 [==============================] - 95s 3ms/step - loss: -2163481595871232.0000 - accuracy: 0.2181 - val_loss: -25717671462961152.0000 - val_accuracy: 0.0000e+00
# Epoch 3/12
# 32859/32859 [==============================] - 100s 3ms/step - loss: -17825722743652352.0000 - accuracy: 0.2179 - val_loss: -158759153949474816.0000 - val_accuracy: 0.0000e+00
# Epoch 4/12
# 32859/32859 [==============================] - 97s 3ms/step - loss: -78352615934525440.0000 - accuracy: 0.2182 - val_loss: -590417884186935296.0000 - val_accuracy: 0.0000e+00
# Epoch 5/12
# 32859/32859 [==============================] - 86s 3ms/step - loss: -243377551643246592.0000 - accuracy: 0.2183 - val_loss: -1654191467050041344.0000 - val_accuracy: 0.0000e+00
# Epoch 6/12
# 32859/32859 [==============================] - 102s 3ms/step - loss: -612849914258391040.0000 - accuracy: 0.2183 - val_loss: -3891267308210880512.0000 - val_accuracy: 0.0000e+00
# Epoch 7/12
# 32859/32859 [==============================] - 87s 3ms/step - loss: -1336630793593683968.0000 - accuracy: 0.2182 - val_loss: -8057017248935575552.0000 - val_accuracy: 0.0000e+00
# Epoch 8/12
# 32859/32859 [==============================] - 95s 3ms/step - loss: -2620859687641284608.0000 - accuracy: 0.2184 - val_loss: -15179701402424311808.0000 - val_accuracy: 0.0000e+00
# Epoch 9/12
# 32859/32859 [==============================] - 90s 3ms/step - loss: -4742099642353713152.0000 - accuracy: 0.2180 - val_loss: -26599145605622136832.0000 - val_accuracy: 0.0000e+00
# Epoch 10/12
# 32859/32859 [==============================] - 103s 3ms/step - loss: -8055291565435781120.0000 - accuracy: 0.2182 - val_loss: -44052302802752372736.0000 - val_accuracy: 0.0000e+00
# Epoch 11/12
# 32859/32859 [==============================] - 134s 4ms/step - loss: -12989145485917814784.0000 - accuracy: 0.2182 - val_loss: -69572306333014687744.0000 - val_accuracy: 0.0000e+00
# Epoch 12/12
# 32859/32859 [==============================] - 112s 3ms/step - loss: -20070553423144026112.0000 - accuracy: 0.2183 - val_loss: -105630407535882141696.0000 - val_accuracy: 0.0000e+00
# 5539/5539 [==============================] - 11s 2ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_binary7,scaled_y_test)
# Out:
# 0.3879818107961726

# %%
from keras.layers import LSTM
lstm_X_train = scaled_X_train.to_numpy().reshape(scaled_X_train.shape[0], 1, scaled_X_train.shape[1])
lstm_X_test = scaled_X_test.to_numpy().reshape(scaled_X_test.shape[0], 1, scaled_X_test.shape[1])
model = Sequential()
model.add(LSTM(324, input_shape=(1,6)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(lstm_X_train, y_train, epochs=12, validation_data=(lstm_X_test, y_test))
# Out:
# Epoch 1/12
#  9412/36510 [======>.......................] - ETA: 7:31 - loss: 0.5042 - accuracy: 0.7872
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6924\2291259121.py in <module>
#       6 model.add(Dense(1, activation='sigmoid'))
#       7 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# ----> 8 model.fit(lstm_X_train, y_train, epochs=12, validation_data=(lstm_X_test, y_test))
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
