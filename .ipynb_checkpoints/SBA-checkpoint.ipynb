# %% [markdown]
# ### **CREDIT-WORTHINESS OF SMALL BUSINESSES**
# #### Case study of small businesses guaranteed by the U.S. Small Business Administration(SBA)

# %% [markdown]
# ### **Business Overview**
#
# The Small Business Administration (SBA) is a crucial organization in the United States that supports and promotes small enterprises by providing access to credit. Through loan guarantees, the SBA encourages lenders to provide credit to small businesses, which play a vital role in job creation and reducing unemployment. However, there have been instances of loan defaults, posing a challenge for the SBA in accurately assessing the creditworthiness of applicants and mitigating risks. To address this, the SBA focuses on evaluating creditworthiness by considering factors such as financial history, business plans, collateral, and projected cash flows. They also strive to adapt to market dynamics, embracing innovative approaches and technology for informed lending decisions that minimize the likelihood of defaults. Overall, the SBA's commitment to supporting small businesses goes beyond loan guarantees, encompassing mentorship programs, training resources, government contracting opportunities, and disaster recovery assistance to foster an environment conducive to small business success.

# %% [markdown]
# ### Project Overview
#
# This project focuses on utilizing the dataset from the U.S. Small Business Administration to develop a predictive model for loan application approval. By analyzing relevant factors and historical loan data, the project aims to create a reliable system that assists the SBA in making informed decisions while minimizing the risk of defaults. The ultimate goal is to provide the SBA with a robust loan approval model that enhances their ability to make accurate and efficient lending decisions.

# %% [markdown]
# ### Objectives
#
# 1. Conduct a comprehensive analysis of the dataset from the U.S. Small Business Administration to identify patterns and trends for accurate loan approval predictions.
# 2. Develop a robust machine learning model that utilizes the identified patterns and trends to predict loan approval outcomes effectively.
# 3. Deploy and evaluate the developed machine learning model in the loan approval process of the U.S. Small Business Administration, continuously optimizing its predictive capabilities for informed lending decisions.

# %% [markdown]
# ### Data Understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 
pd.set_option('display.max_columns', None)

# Data preprocessing and transformation
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

# Classification model libraries
from sklearn.metrics import accuracy_score, precision_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import svm
from sklearn.linear_model import SGDClassifier
import xgboost as xgb
from xgboost import XGBClassifier 

# Pipeline and feature selection
from sklearn.pipeline import Pipeline

# %%
# Reading SBA Data
df = pd.read_csv('data/SBAnational.csv',low_memory=False)
df.head()
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
#    Term  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0    84      4       2.0          0            0              1           0
# 1    60      2       2.0          0            0              1           0
# 2   180      7       1.0          0            0              1           0
# 3    60      2       1.0          0            0              1           0
# 4   240     14       1.0          7            7              1           0
#
#   RevLineCr LowDoc ChgOffDate DisbursementDate DisbursementGross BalanceGross  \
# 0         N      Y        NaN        28-Feb-99       $60,000.00        $0.00
# 1         N      Y        NaN        31-May-97       $40,000.00        $0.00
# 2         N      N        NaN        31-Dec-97      $287,000.00        $0.00
# 3         N      Y        NaN        30-Jun-97       $35,000.00        $0.00
# 4         N      N        NaN        14-May-97      $229,000.00        $0.00
#
#   MIS_Status ChgOffPrinGr        GrAppv      SBA_Appv
# 0      P I F       $0.00    $60,000.00    $48,000.00
# 1      P I F       $0.00    $40,000.00    $32,000.00
# 2      P I F       $0.00   $287,000.00   $215,250.00
# 3      P I F       $0.00    $35,000.00    $28,000.00
# 4      P I F       $0.00   $229,000.00   $229,000.00

# %%
# Reading Foia Data
df2 = pd.read_csv("data/foia-7afy2020-present-asof-230331.csv",encoding='latin-1', engine='python')
df2.head()
# Out:
#    AsOfDate Program                       BorrName  \
# 0  20230331      7A  Allen Foot and Ankle Medicine
# 1  20230331      7A         Cojutepeque Restaurant
# 2  20230331      7A                       Adwa LLC
# 3  20230331      7A                  Town Cleaners
# 4  20230331      7A                      Moor Inc.
#
#                        BorrStreet      BorrCity BorrState  BorrZip  \
# 0     2919 S ELLSWORTH RD STE 124          MESA        AZ    85212
# 1                   2610 W 3rd St   Los Angeles        CA    90057
# 2  3105 ALDERWOOD MALL BLVD Suite      LYNNWOOD        WA    98036
# 3         2700 WASHINGTON BLVD #B     ARLINGTON        VA    22201
# 4                 524 WOODSIDE RD  REDWOOD CITY        CA    94061
#
#                                     BankName  BankFDICNumber  BankNCUANumber  \
# 0                      Western Alliance Bank         57512.0             NaN
# 1                                Banner Bank         28489.0             NaN
# 2                                Umpqua Bank         17266.0             NaN
# 3                                 Hanmi Bank         24170.0             NaN
# 4  JPMorgan Chase Bank, National Association           628.0             NaN
#
#                  BankStreet     BankCity BankState  BankZip  GrossApproval  \
# 0         1 E Washington St      PHOENIX        AZ  85004.0       350000.0
# 1            10 S First Ave  WALLA WALLA        WA  99362.0      1040000.0
# 2  445 SE Main St, First Fl     ROSEBURG        OR  97470.0       987500.0
# 3  3660 Wilshire Blvd, PH-A  LOS ANGELES        CA  90010.0        22000.0
# 4         1111 Polaris Pkwy     COLUMBUS        OH  43240.0        49000.0
#
#    SBAGuaranteedApproval ApprovalDate  ApprovalFiscalYear  \
# 0               175000.0   10/01/2019                2020
# 1               780000.0   10/01/2019                2020
# 2               740625.0   10/01/2019                2020
# 3                11000.0   10/01/2019                2020
# 4                24500.0   10/01/2019                2020
#
#   FirstDisbursementDate DeliveryMethod                   subpgmdesc  \
# 0            10/31/2019     SBA EXPRES  FA$TRK (Small Loan Express)
# 1            10/31/2019            PLP                     Guaranty
# 2            10/31/2019            PLP                     Guaranty
# 3            10/31/2019     SBA EXPRES  FA$TRK (Small Loan Express)
# 4            10/31/2019     SBA EXPRES  FA$TRK (Small Loan Express)
#
#    InitialInterestRate  TermInMonths  NaicsCode  \
# 0                  5.5            63   621391.0
# 1                  6.5           300   722511.0
# 2                  7.0           120   451110.0
# 3                  9.0            51   812320.0
# 4                 11.5           120   445110.0
#
#                                     NaicsDescription FranchiseCode  \
# 0                             Offices of Podiatrists           NaN
# 1                           Full-Service Restaurants           NaN
# 2                              Sporting Goods Stores           NaN
# 3  Drycleaning and Laundry Services (except Coin-...           NaN
# 4  Supermarkets and Other Grocery (except Conveni...           NaN
#
#   FranchiseName ProjectCounty ProjectState              SBADistrictOffice  \
# 0           NaN      MARICOPA           AZ        ARIZONA DISTRICT OFFICE
# 1           NaN   LOS ANGELES           CA    LOS ANGELES DISTRICT OFFICE
# 2           NaN     SNOHOMISH           WA        SEATTLE DISTRICT OFFICE
# 3           NaN     ARLINGTON           VA     WASHINGTON DISTRICT OFFICE
# 4           NaN     SAN MATEO           CA  SAN FRANCISCO DISTRICT OFFICE
#
#    CongressionalDistrict BusinessType                        BusinessAge  \
# 0                    4.0  CORPORATION  Existing or more than 2 years old
# 1                   34.0  CORPORATION  Existing or more than 2 years old
# 2                    1.0  CORPORATION                Change of Ownership
# 3                    8.0   INDIVIDUAL  Existing or more than 2 years old
# 4                   14.0  CORPORATION  Existing or more than 2 years old
#
#   LoanStatus PaidInFullDate ChargeOffDate  GrossChargeOffAmount  \
# 0        PIF     12/31/2022           NaN                     0
# 1     EXEMPT            NaN           NaN                     0
# 2     EXEMPT            NaN           NaN                     0
# 3     CHGOFF            NaN    09/07/2022                 15570
# 4        PIF     01/31/2023           NaN                     0
#
#    RevolverStatus  JobsSupported SOLDSECMRTIND
# 0               0              0             N
# 1               0             12             Y
# 2               0             14             Y
# 3               0              2             Y
# 4               1              0             N

# %%
# Compatibility of dependent variable
df2.LoanStatus.value_counts()
# Out:
# EXEMPT    121746
# COMMIT     17858
# CANCLD     14980
# PIF        13147
# CHGOFF       480
# Name: LoanStatus, dtype: int64

# %%
# Foia Data as a percentage of SBA Data
len(df2)/len(df)
# Out:
# 0.18707488289121896

# %% [markdown]
# Since Foia data is incompatible and of negligible size, we proceed with SBA data only for our analysis

# %%
class Describer:
    
    # initialize object
    def __init__(self, df):
        self.df = df
        
    # method to check shape of data
    def shape(self):
        shape_df = print(f"The DataFrame has:\n\t* {self.df.shape[0]} rows\n\t* {self.df.shape[1]} columns", '\n')
        return shape_df
    
    # method to check info on dataset
    def data_info(self):
        info_df = print(self.df.info(), '\n')
        return info_df
    
    # method to describe numerical columns
    def data_describe(self):
        num_col = self.df.describe()
        return num_col

# %%
# creating an instance of the class describer
describe_df = Describer(df)

# Viewing the shape of the data
describe_df.shape()
# Out:
# The DataFrame has:
# 	* 899164 rows
# 	* 27 columns

# %%
# summary information
print('Summary infomation on dataset')
print('-----------------------------------------------')
describe_df.data_info()
# Out:
# Summary infomation on dataset
# -----------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   LoanNr_ChkDgt      899164 non-null  int64
#  1   Name               899150 non-null  object
#  2   City               899134 non-null  object
#  3   State              899150 non-null  object
#  4   Zip                899164 non-null  int64
#  5   Bank               897605 non-null  object
#  6   BankState          897598 non-null  object
#  7   NAICS              899164 non-null  int64
#  8   ApprovalDate       899164 non-null  object
#  9   ApprovalFY         899164 non-null  object
#  10  Term               899164 non-null  int64
#  11  NoEmp              899164 non-null  int64
#  12  NewExist           899028 non-null  float64
#  13  CreateJob          899164 non-null  int64
#  14  RetainedJob        899164 non-null  int64
#  15  FranchiseCode      899164 non-null  int64
#  16  UrbanRural         899164 non-null  int64
#  17  RevLineCr          894636 non-null  object
#  18  LowDoc             896582 non-null  object
#  19  ChgOffDate         162699 non-null  object
#  20  DisbursementDate   896796 non-null  object
#  21  DisbursementGross  899164 non-null  object
#  22  BalanceGross       899164 non-null  object
#  23  MIS_Status         897167 non-null  object
#  24  ChgOffPrinGr       899164 non-null  object
#  25  GrAppv             899164 non-null  object
#  26  SBA_Appv           899164 non-null  object
# dtypes: float64(1), int64(9), object(17)
# memory usage: 185.2+ MB
# None

# %%
# summary statistics
describe_df.data_describe()
# Out:
#        LoanNr_ChkDgt            Zip          NAICS           Term  \
# count   8.991640e+05  899164.000000  899164.000000  899164.000000
# mean    4.772612e+09   53804.391241  398660.950146     110.773078
# std     2.538175e+09   31184.159152  263318.312759      78.857305
# min     1.000014e+09       0.000000       0.000000       0.000000
# 25%     2.589758e+09   27587.000000  235210.000000      60.000000
# 50%     4.361439e+09   55410.000000  445310.000000      84.000000
# 75%     6.904627e+09   83704.000000  561730.000000     120.000000
# max     9.996003e+09   99999.000000  928120.000000     569.000000
#
#                NoEmp       NewExist      CreateJob    RetainedJob  \
# count  899164.000000  899028.000000  899164.000000  899164.000000
# mean       11.411353       1.280404       8.430376      10.797257
# std        74.108196       0.451750     236.688165     237.120600
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       1.000000       0.000000       0.000000
# 50%         4.000000       1.000000       0.000000       1.000000
# 75%        10.000000       2.000000       1.000000       4.000000
# max      9999.000000       2.000000    8800.000000    9500.000000
#
#        FranchiseCode     UrbanRural
# count  899164.000000  899164.000000
# mean     2753.725933       0.757748
# std     12758.019136       0.646436
# min         0.000000       0.000000
# 25%         1.000000       0.000000
# 50%         1.000000       1.000000
# 75%         1.000000       1.000000
# max     99999.000000       2.000000

# %%
# Duplicates
df.duplicated().any()
# Out:
# False

# %%
# Function to display missing values

def missing_values(data):
    # identify the total missing values per column
    # sort in order 
    if df.isnull().sum().any():
        print(f"The Data has {df.isnull().sum().sum()} missing values in total.")
        miss = data.isnull().sum().sort_values(ascending = False)

        # percentage of missing values
        percentage_miss = (data.isnull().sum() / len(data)).sort_values(ascending = False)

        # store in a dataframe 
        missing = pd.DataFrame({"Missing Values": miss, "Percentage(%)": percentage_miss})

        return missing
    else:
        print("The Data has no missing values")


missing_values(df)
# Out:
# The Data has 751259 missing values in total.
#                    Missing Values  Percentage(%)
# ChgOffDate                 736465       0.819055
# RevLineCr                    4528       0.005036
# LowDoc                       2582       0.002872
# DisbursementDate             2368       0.002634
# MIS_Status                   1997       0.002221
# BankState                    1566       0.001742
# Bank                         1559       0.001734
# NewExist                      136       0.000151
# City                           30       0.000033
# State                          14       0.000016
# Name                           14       0.000016
# LoanNr_ChkDgt                   0       0.000000
# GrAppv                          0       0.000000
# ChgOffPrinGr                    0       0.000000
# BalanceGross                    0       0.000000
# DisbursementGross               0       0.000000
# CreateJob                       0       0.000000
# UrbanRural                      0       0.000000
# FranchiseCode                   0       0.000000
# RetainedJob                     0       0.000000
# NoEmp                           0       0.000000
# Term                            0       0.000000
# ApprovalFY                      0       0.000000
# ApprovalDate                    0       0.000000
# NAICS                           0       0.000000
# Zip                             0       0.000000
# SBA_Appv                        0       0.000000

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# We drop the column ```ChgOffDate```, representing the **date when a loan is declared to be in default**, due to the high percentage of missing values.

# %%
# Dropping the ChgOffDate column
df.drop('ChgOffDate', axis = 1, inplace=True)

# %%
# Checking the unique values in the target variable
df['MIS_Status'].unique()
# Out:
# array(['P I F', 'CHGOFF', nan], dtype=object)

# %%
# Checking the percentage of data retained if we choose to drop all rows with missing values 
len(df.dropna())/len(df)
# Out:
# 0.9856266487537313

# %% [markdown]
# Since we still have a very significant amount of data(```98.5%```) retained after dropping the missing values, we proceed and drop them.

# %%
# Dropping all rows with missing values
df.dropna(inplace=True)

# %%
# Confirming that we have dropped all rows with missing values
df.isnull().sum().any()
# Out:
# False

# %% [markdown]
# Next, we remove the dollar signs to facilitate data manipulation and for consistency.

# %%
# Removing the dollar signs in the currency columns
dollar_columns = ['DisbursementGross', 'BalanceGross', 'ChgOffPrinGr', 'GrAppv', 'SBA_Appv']
df[dollar_columns] = df[dollar_columns].replace('[\$,]', '', regex=True).astype(float)

# %%
date_columns=['ApprovalDate','DisbursementDate']
for column in date_columns:
    df[column]=pd.to_datetime(df[column])

# %% [markdown]
# Checking for inconsistencies / invalid data

# %%
invalid_data=df[df.DisbursementDate<df.ApprovalDate]
invalid_data
# Out:
#         LoanNr_ChkDgt                            Name             City State  \
# 760        7890211003  DOBERSTEIN LUMBER & FENCE, INC          MEDFORD    WI
# 1125       1003703008    AQUA BELLA ENTERPRISES, INC.          CHICAGO    IL
# 1541       1168343005            MR. BURKS RESTAURANT          MAYWOOD    IL
# 3741       1643713009           AUTOMATED PROCESS INC        MILWAUKEE    WI
# 3894       1671373000                       C'S MOTEL   DELTA JUNCTION    AK
# ...               ...                             ...              ...   ...
# 886230     3674931004             LAMBERT ADVERTISING            SANDY    UT
# 886231     2329581000               RICHARD SIMS ETAL        LITTLETON    CO
# 886236     1779841009                  MEJANS C/O SBA  KING OF PRUSSIA    PA
# 886238     3675371004             AMERICAN CINEMA INC   SALT LAKE CITY    UT
# 886239     3525321005  SENTRY AUTOMATIC FIRE ALARM CO         NEW CITY    NY
#
#           Zip                            Bank BankState  NAICS ApprovalDate  \
# 760     54451           NICOLET NATIONAL BANK        WI      0   1979-06-07
# 1125    60634            NORTH COMMUNITY BANK        IL      0   1980-06-25
# 1541    60153           FIRSTMERIT BANK, N.A.        IL      0   1981-02-06
# 3741    53223  U.S. BANK NATIONAL ASSOCIATION        WI      0   1983-08-01
# 3894    99737    KEYBANK NATIONAL ASSOCIATION        AK      0   1983-08-29
# ...       ...                             ...       ...    ...          ...
# 886230  84091       ZIONS FIRST NATIONAL BANK        UT      0   2072-10-26
# 886231  80121                       FIRSTBANK        CO      0   2072-10-27
# 886236  19064  PNC BANK, NATIONAL ASSOCIATION        DE      0   2072-12-01
# 886238  84102     WELLS FARGO BANK NATL ASSOC        SD      0   2072-12-05
# 886239  10956  JPMORGAN CHASE BANK NATL ASSOC        OH      0   2072-12-08
#
#        ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 760          1979    24      2       1.0          0            0
# 1125         1980    87     20       1.0          0            0
# 1541         1981   123      1       2.0          0            0
# 3741         1983    51     30       1.0          0            0
# 3894         1983   122      9       1.0          0            0
# ...           ...   ...    ...       ...        ...          ...
# 886230       1973   180      3       1.0          0            0
# 886231       1973   318     21       2.0          0            0
# 886236       1973    96      6       1.0          0            0
# 886238       1973   147      4       1.0          0            0
# 886239       1973   180     18       1.0          0            0
#
#         FranchiseCode  UrbanRural RevLineCr LowDoc DisbursementDate  \
# 760                 0           0         N      N       1979-04-17
# 1125                0           0         N      N       1980-05-12
# 1541                0           0         N      N       1980-12-05
# 3741                0           0         N      N       1983-05-04
# 3894                0           0         N      N       1983-03-13
# ...               ...         ...       ...    ...              ...
# 886230              0           0         N      N       1973-01-16
# 886231              0           0         N      N       1973-02-20
# 886236              0           0         N      N       1973-09-13
# 886238              0           0         N      N       1973-01-03
# 886239              0           0         N      N       1973-01-18
#
#         DisbursementGross  BalanceGross MIS_Status  ChgOffPrinGr    GrAppv  \
# 760              250000.0           0.0     CHGOFF       38229.0  250000.0
# 1125             350000.0           0.0     CHGOFF      311636.0  350000.0
# 1541             110000.0           0.0     CHGOFF       23010.0  110000.0
# 3741             300000.0           0.0     CHGOFF      182855.0  300000.0
# 3894             285000.0           0.0     CHGOFF       34952.0  285000.0
# ...                   ...           ...        ...           ...       ...
# 886230            45000.0           0.0     CHGOFF        3934.0   45000.0
# 886231           300000.0           0.0     CHGOFF       68340.0  300000.0
# 886236            45000.0           0.0     CHGOFF       23330.0   45000.0
# 886238           200000.0           0.0     CHGOFF      113859.0  200000.0
# 886239           300000.0           0.0      P I F          28.0  300000.0
#
#         SBA_Appv
# 760     225000.0
# 1125    315000.0
# 1541     99000.0
# 3741    240000.0
# 3894    256500.0
# ...          ...
# 886230   40500.0
# 886231  270000.0
# 886236   31500.0
# 886238  180000.0
# 886239  270000.0
#
# [784 rows x 26 columns]

# %%
# Dropping Inconsistencies
df.drop(invalid_data.index,axis=0,inplace=True)

# %%
# Confirming Drop
len(df[df.DisbursementDate<df.ApprovalDate])
# Out:
# 0

# %%
# Sorting the DataFrame
df = df.sort_values(by=['ApprovalDate']).reset_index(drop=True)

# %%
# Displaying the DataFrame
df.head()
# Out:
#    LoanNr_ChkDgt                            Name        City State    Zip  \
# 0     2357951001                    WINSLOW CORP      BERLIN    NJ   8009
# 1     4160941004                    THE BUCKSKIN     QUEMADO    NM  87829
# 2     3527741006                MOBICENTRICS INC       BRONX    NY  10451
# 3     3227931002  AMERICANA INSTITUTE OF DAY CAR  GLEN ARDEN    MD  20027
# 4     5090841007                   JAMES E SEARS     LINCOLN    NE  68502
#
#                              Bank BankState  NAICS ApprovalDate ApprovalFY  \
# 0  PNC BANK, NATIONAL ASSOCIATION        NJ      0   1973-02-06       1973
# 1                FIRST STATE BANK        NM      0   1973-02-14       1973
# 2      BANK OF AMERICA NATL ASSOC        NY      0   1973-02-23       1973
# 3      BANK OF AMERICA NATL ASSOC        VA      0   1973-02-28       1973
# 4                        THE BANK        KS      0   1973-03-07       1973
#
#    Term  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0   120      5       1.0          0            0              0           0
# 1   230      2       1.0          0            0              0           0
# 2   180     16       1.0          0            0              0           0
# 3   120      1       2.0          0            0              0           0
# 4   168      1       1.0          0            0          17750           0
#
#   RevLineCr LowDoc DisbursementDate  DisbursementGross  BalanceGross  \
# 0         N      N       1973-02-27           200000.0           0.0
# 1         N      N       1973-06-08           155000.0           0.0
# 2         N      N       1973-03-29           150000.0           0.0
# 3         N      N       1973-04-12            70000.0           0.0
# 4         N      N       1973-03-16            18000.0           0.0
#
#   MIS_Status  ChgOffPrinGr    GrAppv  SBA_Appv
# 0     CHGOFF      199955.0  200000.0  180000.0
# 1     CHGOFF       71574.0  155000.0  139500.0
# 2     CHGOFF       10471.0  150000.0  135000.0
# 3     CHGOFF           0.0   70000.0   63000.0
# 4     CHGOFF         175.0   18000.0   16200.0

# %% [markdown]
# Cleaning NewExist Column (Whether a business is new or has been in operation)

# %%
# Checking Value Counts
df.NewExist.value_counts()
# Out:
# 1.0    636303
# 2.0    249153
# Name: NewExist, dtype: int64

# %%
# Replacing 0.0 values with null
df.NewExist=df.NewExist.replace(0.0,np.nan)

# %%
# Backfilling null values
df.NewExist=df.NewExist.backfill()

# %%
# Confirming replacement
df.NewExist.isnull().sum()
# Out:
# 0

# %%
# Displaying value counts
df.NewExist.value_counts()
# Out:
# 1.0    636303
# 2.0    249153
# Name: NewExist, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
# Computing SBA Approved as a percentage of Gross Approved
df['PercentageAprroved']=(df.SBA_Appv/df.GrAppv)*100
df['PercentageAprroved']=round(df['PercentageAprroved'],1).astype(int)
df['PercentageAprroved'].mean()
# Out:
# 70.84415148804683

# %%
# Engineering Industry Column
df['Industry'] = df['NAICS'].astype('str').apply(lambda x: x[:2])
df['Industry'] = df['Industry'].map({
    '11': 'Ag/For/Fish/Hunt',
    '21': 'Min/Quar/Oil_Gas_ext',
    '22': 'Utilities',
    '23': 'Construction',
    '31': 'Manufacturing',
    '32': 'Manufacturing',
    '33': 'Manufacturing',
    '42': 'Wholesale_trade',
    '44': 'Retail_trade',
    '45': 'Retail_trade',
    '48': 'Trans/Ware',
    '49': 'Trans/Ware',
    '51': 'Information',
    '52': 'Finance/Insurance',
    '53': 'RE/Rental/Lease',
    '54': 'Prof/Science/Tech',
    '55': 'Mgmt_comp',
    '56': 'Admin_sup/Waste_Mgmt_Rem',
    '61': 'Educational',
    '62': 'Healthcare/Social_assist',
    '71': 'Arts/Entertain/Rec',
    '72': 'Accom/Food_serv',
    '81': 'Other_no_pub',
    '92': 'Public_Admin',
    '0': 'Other'
})

# %% [markdown]
# ## Feature Selection

# %%
relevant_columns=['GrAppv', 'Term', 'NoEmp','NewExist', 'UrbanRural', 'Industry','MIS_Status']
df=df.loc[:,relevant_columns]
df
# Out:
#           GrAppv  Term  NoEmp  NewExist  UrbanRural Industry MIS_Status
# 0       200000.0   120      5       1.0           0    Other     CHGOFF
# 1       155000.0   230      2       1.0           0    Other     CHGOFF
# 2       150000.0   180     16       1.0           0    Other     CHGOFF
# 3        70000.0   120      1       2.0           0    Other     CHGOFF
# 4        18000.0   168      1       1.0           0    Other     CHGOFF
# ...          ...   ...    ...       ...         ...      ...        ...
# 886232  350000.0   264      4       2.0           0    Other      P I F
# 886233   28000.0   162      3       1.0           0    Other     CHGOFF
# 886234  100000.0    84     40       2.0           0    Other     CHGOFF
# 886235  200000.0   102     30       1.0           0    Other     CHGOFF
# 886237   20000.0    84      5       1.0           0    Other     CHGOFF
#
# [885456 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 885456 entries, 0 to 886237
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   GrAppv      885456 non-null  float64
#  1   Term        885456 non-null  int64
#  2   NoEmp       885456 non-null  int64
#  3   NewExist    885456 non-null  float64
#  4   UrbanRural  885456 non-null  int64
#  5   Industry    885456 non-null  object
#  6   MIS_Status  885456 non-null  object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.0+ MB

# %% [markdown]
# # **EDA**

# %%
df.columns
# Out:
# Index(['GrAppv', 'Term', 'NoEmp', 'NewExist', 'UrbanRural', 'Industry',
#        'MIS_Status'],
#       dtype='object')

# %% [markdown]
# ## **Univariate Analysis**

# %%
colors=['black','blue','green','orange','pink']
columns = df.select_dtypes(['int64','float64']).columns
def plot_histograms(df, columns):
    fig, axs = plt.subplots(ncols=1, nrows=len(columns), figsize=(6,12))
    for i, col in enumerate(columns):
        axs[i].hist(df[col], bins=50,color=colors[i])
        axs[i].set_title(col)
    plt.subplots_adjust(wspace=0.2,hspace=0.4)
    plt.show()
plot_histograms(df,columns)

# %% [markdown]
# More loans taken up were cleared fully(```82.3%```), while a smaller percentage(```17.6%```) of the loans taken up were defaulted.
# Imbalance will be solved later by oversampling.

# %% [markdown]
# <b> Observation: </b> The amount of loans that are Paid in Full & Charged Off, are irrespective of the Term Limit of the loan.

# %% [markdown]
# These histogram plots illustrate the distribution of data for the numerical columns in the dataframe.
#
# Next, we will look for any outliers in the dataframe.

# %%
# Calculate the IQR
Q1 = df['DisbursementGross'].quantile(0.25)
Q3 = df['DisbursementGross'].quantile(0.75)
IQR = Q3 - Q1
# Define the lower and upper bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Filter the outliers
outliers = df[(df['DisbursementGross'] < lower_bound) | (df['DisbursementGross'] > upper_bound)]
# Print the outliers
print(outliers)
# Out:
#         LoanNr_ChkDgt                            Name            City State  \
# 158        8260831001  WALKER-NEER MANUFACTURING CO.,   WICHITA FALLS    TX
# 229        8455081001     BECKER ELECTRONICS MFG CORP     EAST DURHAM    NY
# 243        8534501005               LUCID LINES, INC.     LOS ANGELES    CA
# 256        8420021005    CALDWELL PORT ELEVATOR, INC.        COLUMBIA    LA
# 297        8926061003           EVA DAWN NURSING HOME  SALT LAKE CITY    UT
# ...               ...                             ...             ...   ...
# 886101     6699115000  Argos Global Partner Services,    Key Biscayne    FL
# 886109     6708075004        SCA Pharmaceuticals, LLC     LITTLE ROCK    AR
# 886119     6724455000  D & D Mulch and Landscape, Inc      Bellingham    MA
# 886132     6765475002           WATERPROOF DRUG, INC.        FERRIDAY    LA
# 886141     6812465003  Holmes Property Investments, L        Magnolia    TX
#
#           Zip                            Bank BankState   NAICS ApprovalDate  \
# 158     76307      BANK OF AMERICA NATL ASSOC        TX       0   1976-07-29
# 229     12423  JPMORGAN CHASE BANK NATL ASSOC        OH       0   1977-03-25
# 243     90034              CITY NATIONAL BANK        CA       0   1977-04-26
# 256     71418            FDIC/2529 BANK DIXIE        LA       0   1977-05-16
# 297     84103  JPMORGAN CHASE BANK NATL ASSOC        AZ       0   1977-09-27
# ...       ...                             ...       ...     ...          ...
# 886101  33149                  CITIBANK, N.A.        SD  423120   2014-02-27
# 886109  72205    ARKANSAS CAPITAL CORPORATION        AR  424210   2014-03-05
# 886119   2019              CHARLES RIVER BANK        MA  561730   2014-03-14
# 886132  71334            FIRST FINANCIAL BANK        AR  446110   2014-04-07
# 886141  77354     WELLS FARGO BANK NATL ASSOC        SD  451110   2014-05-05
#
#        ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 158         1976A   174    110       1.0          0            0
# 229          1977   120    194       1.0          0            0
# 243          1977    84    200       1.0          0            0
# 256          1977   120      5       1.0          0            0
# 297          1977   110     12       1.0          0            0
# ...           ...   ...    ...       ...        ...          ...
# 886101       2014    12     14       1.0          2           14
# 886109       2014   120     21       1.0         14           21
# 886119       2014   120     43       1.0          4           43
# 886132       2014   120     14       1.0          0           14
# 886141       2014   300     35       1.0         35            0
#
#         FranchiseCode  UrbanRural RevLineCr LowDoc DisbursementDate  \
# 158                 0           0         N      N       1977-01-28
# 229                 0           0         N      N       1977-06-03
# 243                 0           0         N      N       1977-07-22
# 256                 0           0         N      N       1978-05-31
# 297                 0           0         N      N       1978-01-10
# ...               ...         ...       ...    ...              ...
# 886101              0           2         Y      N       2014-02-27
# 886109              0           1         N      N       2014-04-01
# 886119              0           1         N      N       2014-03-14
# 886132              0           2         N      N       2014-04-07
# 886141              0           1         N      N       2014-05-05
#
#         DisbursementGross  BalanceGross MIS_Status  ChgOffPrinGr     GrAppv  \
# 158              650000.0           0.0     CHGOFF      253484.0   750000.0
# 229              550000.0           0.0     CHGOFF           0.0   550000.0
# 243              550000.0           0.0     CHGOFF      317147.0   550000.0
# 256              555000.0           0.0     CHGOFF      439164.0   555000.0
# 297              555000.0           0.0     CHGOFF      262833.0   555000.0
# ...                   ...           ...        ...           ...        ...
# 886101          3000000.0           0.0      P I F           0.0  3000000.0
# 886109          2800000.0           0.0      P I F           0.0  2800000.0
# 886119          1250000.0           0.0      P I F           0.0  1250000.0
# 886132          1185000.0           0.0      P I F           0.0  1185000.0
# 886141           637200.0           0.0      P I F           0.0   637200.0
#
#          SBA_Appv  PercentageAprroved                  Industry
# 158      499500.0                  66                     Other
# 229      495000.0                  90                     Other
# 243      495000.0                  90                     Other
# 256      444000.0                  80                     Other
# 297      499500.0                  90                     Other
# ...           ...                 ...                       ...
# 886101  2700000.0                  90           Wholesale_trade
# 886109  2100000.0                  75           Wholesale_trade
# 886119   937500.0                  75  Admin_sup/Waste_Mgmt_Rem
# 886132   888750.0                  75              Retail_trade
# 886141   477900.0                  75              Retail_trade
#
# [82542 rows x 28 columns]

# %%
# # Select the relevant columns for analysis
# selected_columns = ['LoanNr_ChkDgt', 'City', 'State', 'Zip', 'Bank', 'NAICS',
#                     'RevLineCr', 'LowDoc', 'DisbursementGross', 'MIS_Status']
# # Subset the DataFrame with selected columns
# subset_df = df[selected_columns]

# # Perform bivariate analysis
# sns.set(style="ticks")
# sns.pairplot(subset_df, hue='MIS_Status')
# plt.show()

# %% [markdown]
# ### Multivariate Analysis
#
# 1. Correlation Matrix

# %%
# Create a new DataFrame for encoded variables
# Perform label encoding on each categorical column
encoded_df=pd.DataFrame()
for column in df.columns:
    if df[column].dtype == 'object':
        encoded_df[column] = df[column].astype('category').cat.codes
    else:
        encoded_df[column] = df[column]

# Calculate the correlation matrix
correlation_matrix = encoded_df.corr()

# Plot the correlation matrix using a heatmap

plt.figure(figsize=(27, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# * From the matrix, it is clear that the higher the job creation the higher the retention rate since the two have a correlation of ```99%```.

# %% [markdown]
# ***SBA data, many of the categorical variables, such as state, city, and bank, have no inherent order and there are many categories. Using label encoding
# on these variables could potentially introduce unintended patterns or biases in the data, as there is no relationship or hierarchy between the categories.***
#
# ***We performed label encoding to transform the categorical variables into numerical to enable visualization on a heatmap.
# Mention the variables that have a high correlation, which ones should be dropped and why.
# Observe the accuracy level of the SBA_Approv vs GrAPPV VIS A VIS our accuracy level/target accuracy.***

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ### Encoding

# %%
encoded_df=pd.DataFrame()
for column in relevant_df.columns:
    if relevant_df[column].dtype == 'object':
        encoded_df[column] = relevant_df[column].astype('category').cat.codes
    else:
        encoded_df[column] = relevant_df[column]

# %%
encoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886240 entries, 0 to 886239
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   GrAppv      886240 non-null  float64
#  1   Term        886240 non-null  int64
#  2   NoEmp       886240 non-null  int64
#  3   NewExist    886240 non-null  float64
#  4   UrbanRural  886240 non-null  int64
#  5   Industry    886240 non-null  int8
#  6   MIS_Status  886240 non-null  int8
# dtypes: float64(2), int64(3), int8(2)
# memory usage: 35.5 MB

# %%
encoded_df[:5]
# Out:
#      GrAppv  Term  NoEmp  NewExist  UrbanRural  Industry  MIS_Status
# 0  200000.0   120      5       1.0           0        12           0
# 1  155000.0   230      2       1.0           0        12           0
# 2  150000.0   180     16       1.0           0        12           0
# 3   70000.0   120      1       2.0           0        12           0
# 4   18000.0   168      1       1.0           0        12           0

# %%
# Calculate the correlation matrix
correlation_matrix = encoded_df.corr()

# Plot the correlation matrix using a heatmap

plt.figure(figsize=(27, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Train Test Split

# %%
X=encoded_df.drop('MIS_Status',axis=1)
y=encoded_df['MIS_Status']

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %% [markdown]
# ### Resampling

# %%
sampler=RandomOverSampler(sampling_strategy='minority')
X_train, y_train = sampler.fit_resample(X_train,y_train)

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: MIS_Status, dtype: float64

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
y_train_df=pd.DataFrame(y_train,columns=['MIS_Status'])
train_data=pd.concat([X_train,y_train_df],axis=1)
scaler.fit(train_data)
scaled_train_data=pd.DataFrame(scaler.transform(train_data),columns=relevant_columns)
scaled_train_data
# Out:
#            GrAppv      Term     NoEmp  NewExist  UrbanRural  Industry  \
# 0       -0.247342 -0.051414 -0.082993 -0.637215   -1.391410 -0.456304
# 1       -0.581611 -0.078782 -0.126384  1.569329    0.250569  0.384338
# 2        2.571799  1.234897 -0.025137 -0.637215    1.892548 -1.465075
# 3       -0.439451 -0.078782 -0.068529  1.569329   -1.391410 -1.128818
# 4       -0.439451  0.413848 -0.111921  1.569329    1.892548  0.552466
# ...           ...       ...       ...       ...         ...       ...
# 1168303 -0.247342 -0.831411 -0.039601 -0.637215    0.250569 -0.792561
# 1168304 -0.550874 -0.297729 -0.111921  1.569329    0.250569 -1.633203
# 1168305 -0.497083 -0.776674 -0.097457  1.569329    0.250569 -1.633203
# 1168306 -0.401029 -1.009305 -0.082993 -0.637215    1.892548 -0.288176
# 1168307 -0.247342 -1.173515  0.076111 -0.637215    0.250569 -0.288176
#
#          MIS_Status
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1168303        -1.0
# 1168304        -1.0
# 1168305        -1.0
# 1168306        -1.0
# 1168307        -1.0
#
# [1168308 rows x 7 columns]

# %%
scaled_train_data
# Out:
#            GrAppv      Term     NoEmp  NewExist  UrbanRural  Industry  \
# 0       -0.247342 -0.051414 -0.082993 -0.637215   -1.391410 -0.456304
# 1       -0.581611 -0.078782 -0.126384  1.569329    0.250569  0.384338
# 2        2.571799  1.234897 -0.025137 -0.637215    1.892548 -1.465075
# 3       -0.439451 -0.078782 -0.068529  1.569329   -1.391410 -1.128818
# 4       -0.439451  0.413848 -0.111921  1.569329    1.892548  0.552466
# ...           ...       ...       ...       ...         ...       ...
# 1168303 -0.247342 -0.831411 -0.039601 -0.637215    0.250569 -0.792561
# 1168304 -0.550874 -0.297729 -0.111921  1.569329    0.250569 -1.633203
# 1168305 -0.497083 -0.776674 -0.097457  1.569329    0.250569 -1.633203
# 1168306 -0.401029 -1.009305 -0.082993 -0.637215    1.892548 -0.288176
# 1168307 -0.247342 -1.173515  0.076111 -0.637215    0.250569 -0.288176
#
#          MIS_Status
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1168303        -1.0
# 1168304        -1.0
# 1168305        -1.0
# 1168306        -1.0
# 1168307        -1.0
#
# [1168308 rows x 7 columns]

# %%
y_test_df=pd.DataFrame(y_test,columns=['MIS_Status'])
test_data = pd.concat([X_test,y_test_df],axis=1)
scaled_test_data=pd.DataFrame(scaler.transform(test_data),columns=relevant_columns)
scaled_test_data
# Out:
#           GrAppv      Term     NoEmp  NewExist  UrbanRural  Industry  \
# 0      -0.224289 -0.215624 -0.082993  1.569329    0.250569  0.384338
# 1      -0.343397 -0.407202 -0.097457 -0.637215    0.250569 -0.288176
# 2      -0.535505 -0.106150 -0.039601 -0.637215    0.250569 -0.624433
# 3       0.521092 -0.653517 -0.082993 -0.637215    0.250569  0.384338
# 4      -0.042554  0.413848 -0.097457 -0.637215    1.892548  0.384338
# ...          ...       ...       ...       ...         ...       ...
# 177243 -0.535505 -0.571412 -0.068529 -0.637215    0.250569 -0.288176
# 177244 -0.593138 -1.022989 -0.126384  1.569329    0.250569 -1.128818
# 177245 -0.554716 -0.735622 -0.082993 -0.637215    0.250569  1.561237
# 177246  2.353809  2.055947  0.003791 -0.637215    1.892548  0.552466
# 177247 -0.612349 -0.078782 -0.126384  1.569329    0.250569  0.552466
#
#         MIS_Status
# 0             -1.0
# 1              1.0
# 2              1.0
# 3             -1.0
# 4              1.0
# ...            ...
# 177243         1.0
# 177244        -1.0
# 177245        -1.0
# 177246         1.0
# 177247         1.0
#
# [177248 rows x 7 columns]

# %% [markdown]
# ### Reformating

# %%
scaled_X_train=scaled_train_data.drop('MIS_Status',axis=1)
scaled_y_train=scaled_train_data['MIS_Status']
scaled_X_test=scaled_test_data.drop('MIS_Status',axis=1)
scaled_y_test=scaled_test_data['MIS_Status']

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Expected Input
# 1. Business Name
# 2. Amount of Loan
# 3. Loan Repayment Period
# 4. Pay Previous Loan Status
# 5. No.of Employees
# 6. Business Location
# 7. Business Industry
# 8. How long has business been in operation
#
# #### Expected Output
# 1. Whether loan is guaranteed or not
# 2. Major factors that led to loan results
# 3. Most Probable Banks

# %%
scaled_y_train.value_counts(normalize=True)
# Out:
#  1.0    0.5
# -1.0    0.5
# Name: MIS_Status, dtype: float64

# %% [markdown]
# This is a binary classification task

# %% [markdown]
# **Suitable Models**
#
# `logistic regression`- Grace
#
# `decision tree` - Stella
#
# `random forest` - Josiah
#
# `support vector machine` - Lynne
#
# `XGBoost` - Leo
#
# `neural network` - Brian

# %% [markdown]
# ### <b> <span style="color:teal">Logistic Regression</span>

# %%
class LogisticRegressionModel:
    def __init__(self):
        self.model = LogisticRegression()

    def train(self, scaled_X_train, scaled_y_train):
        self.model.fit(scaled_X_train, scaled_y_train)

    def predict(self, scaled_X_test):
        return self.model.predict(scaled_X_test)

    def evaluate(self, scaled_X_test, scaled_y_test):
        return self.model.score(scaled_X_test, scaled_y_test)

# Create an instance of the logistic regression model
logreg_model = LogisticRegressionModel()

# Train the model on the scaled training data
logreg_model.train(scaled_X_train, scaled_y_train)

# Predict on the scaled test data
y_pred = logreg_model.predict(scaled_X_test)

# Evaluate the model on the scaled test data
accuracy = logreg_model.evaluate(scaled_X_test, scaled_y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7428856743094422

# %% [markdown]
# ### <b> <span style="color:teal">Decision Tree</span>

# %%
class DecisionTreeModel:
    def __init__(self):
        self.model = DecisionTreeClassifier()

    def train(self, scaled_X_train, scaled_y_train):
        self.model.fit(scaled_X_train, scaled_y_train)

    def predict(self, scaled_X_test):
        return self.model.predict(scaled_X_test)

    def evaluate(self, scaled_X_test, scaled_y_test):
        return self.model.score(scaled_X_test, scaled_y_test)

# Create an instance of the decision tree model
tree_model = DecisionTreeModel()

# Train the model on the scaled training data
tree_model.train(scaled_X_train, scaled_y_train)

# Predict on the scaled test data
y_pred = tree_model.predict(scaled_X_test)

# Evaluate the model on the scaled test data
accuracy = tree_model.evaluate(scaled_X_test, scaled_y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8938831467773967

# %% [markdown]
# The model is overfitting

# %% [markdown]
# ### <b> <span style="color:teal">Random Forest </span>

# %%
class RandomForestModel:
    def __init__(self, n_estimators=100, max_depth=None):
        self.model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)

    def train(self, scaled_X_train, scaled_y_train):
        self.model.fit(scaled_X_train, scaled_y_train)

    def predict(self, scaled_X_test):
        return self.model.predict(scaled_X_test)

    def evaluate(self, scaled_X_test, scaled_y_test):
        y_pred = self.predict(scaled_X_test)
        accuracy = accuracy_score(scaled_y_test, y_pred)
        return accuracy

# %%
# Create an instance of the random forest model with custom parameters
rf_model = RandomForestModel(n_estimators=100, max_depth=10)

# Train the model on the scaled training data
rf_model.train(scaled_X_train, scaled_y_train)

# Evaluate the model on the scaled test data
accuracy = rf_model.evaluate(scaled_X_test, scaled_y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8772623668532226

# %% [markdown]
# ### <b> <span style="color:teal">Support Vector Machine</span>

# %%
class SVMModel:
    def __init__(self):
        self.model = svm.SVC()

    def train(self, scaled_X_train, scaled_y_train):
        self.model.fit(scaled_X_train, scaled_y_train)

    def predict(self, scaled_X_test):
        return self.model.predict(scaled_X_test)

    def evaluate(scaled_self, scaled_X_test, scaled_y_test):
        y_pred = self.predict(scaled_X_test)
        accuracy = accuracy_score(scaled_y_test, y_pred)
        return accuracy

# %%
# Creating an instance of SGDClassifier with the 'hinge' loss function
svm_model = SGDClassifier(loss='hinge')

# Training the model on the training data
svm_model.fit(scaled_X_train, scaled_y_train)
# Out:
# SGDClassifier()

# %%
# Predicting on the scaled test data
y_pred = svm_model.predict(scaled_X_test)

# %%
# predicting on the scaled train data
y_pred_train = svm_model.predict(scaled_X_train)

# Calculating the accuracy of the modle on the train data
accuracy_train = accuracy_score(scaled_y_train,y_pred_train)
print("Training Accuracy:", accuracy_train)
# Out:
# Training Accuracy: 0.7796822413267734

# %%
# Calculating the accuracy of the model on the test data
accuracy = svm_model.score(scaled_X_test, scaled_y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7597039176746705

# %% [markdown]
# ### <b> <span style="color:teal">XGBoost</span>

# %%
class XGBoostModel:
    def __init__(self):
        self.model = XGBClassifier()
    
    def train(self, scaled_X_train, scaled_y_train):
        self.model.fit(scaled_X_train, scaled_y_train)
    
    def predict(self, scaled_X_test):
        return self.model.predict(scaled_X_test)
    
    def evaluate(self, scaled_X_test, scaled_y_test):
        y_pred = self.predict(scaled_X_test)
        accuracy = accuracy_score(scaled_y_test, y_pred)
        return accuracy

# Create an instance of the XGBoostModel class
xgboost_model = XGBoostModel()

# Train the model
xgboost_model.train(scaled_X_train, y_train)

# Evaluate the model on the test set
accuracy = xgboost_model.evaluate(scaled_X_test, scaled_y_test)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9082077089727387

# %% [markdown]
# ### <b> <span style="color:teal">Neural Network</span>

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten

model = Sequential()
model.add(Flatten(input_shape=(6, 1))) # Flatten 2D image to 1D vector
model.add(Dense(128, activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.optimizer.lr.assign(0.0001)

model.fit(scaled_X_train, y_train, epochs=100, batch_size=20, validation_split=0.1)

# Make binary predictions on the test data
y_pred = model.predict(scaled_X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
# Out:
